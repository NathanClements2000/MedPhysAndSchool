# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import matplotlib
import scipy as sp
from scipy.interpolate import interp1d

font = {'family' : 'Arial',
        'weight' : 'normal',
        'size'   : 22}

matplotlib.rc('font', **font)

figure(1,figsize=(10,10))
plt.plot([1,2],[1,2],c='black',label='250 MeV')
plt.plot([1,2],[1,2],c='black',label='150 MeV',ls='--')
plt.plot([1,2],[1,2],c='black',label='RT-plan',ls=':')
plt.legend()
