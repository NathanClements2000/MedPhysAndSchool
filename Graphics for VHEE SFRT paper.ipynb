# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import matplotlib
from random import randint

j=0
i=2
f = open("d:Desktop/SFRT-Topas/vhee/vhee_patient/shaped_beam/graphics_attempt1.txt", "w")
f.write('''
includeFile= ./HUToMaterialSchneider.txt
# graphics
includeFile = ./graphics_settings.txt #uncomment if graphics used
b:Gr/Enable = "True"
Ts/UseQt = "True"
s:Gr/MyOGL/BackgroundColor = "white"

sv:Ma/W_EGS/Components = 1 "Tungsten"
uv:Ma/W_EGS/Fractions = 1 1.0
d:Ma/W_EGS/Density = 19.3 g/cm3 #per EGSnrc PEGS4 data used by Chris or use 19.25
s:Ma/W_EGS/DefaultColor="Brown"
i:Ma/W_EGS/AtomicNumber = 74
d:Ma/W_EGS/AtomicMass = 183.85 g/mole #or 183.84 (ICRU 2016 value)
  

#Physics
sv:Ph/Default/Modules = 1 "g4em-standard_opt4"
d:Ph/Default/CutforAllParticles= 0.01 cm

# Geometry
Ge/World/HLX=2.0 m
Ge/World/HLY=2.0 m
Ge/World/HLZ=2.0 m
b:Ge/World/Invisible = "true"
s:Ge/World/Material = "Air"
s:Ge/World/Color = "white"

s:Ge/BeamPosition/Parent = "World"
s:Ge/BeamPosition/Type="Group"
d:Ge/BeamPosition/TransX= 240 mm #'''+str(11.644+240*np.cos(j*np.pi/180))+''' mm #20 cm +4 cause no collimator
d:Ge/BeamPosition/TransY= 0 mm #'''+str(15.594+215*np.sin(j*np.pi/180))+''' mm #20 cm +4 cause no collimator
d:Ge/BeamPosition/TransZ= 0 mm #-11.52 mm
d:Ge/BeamPosition/RotX= 0. deg
d:Ge/BeamPosition/RotY= 90. deg

d:Ge/BeamPosition/RotZ= 0. deg


s:Ge/BeamPos/Parent = "BeamPosition"
s:Ge/BeamPos/Type = "Group"
d:Ge/BeamPos/RotX= -'''+str(j)+''' deg


#Mark source
s:Ge/DemoBox/Type                    = "TsBox"
s:Ge/DemoBox/Parent                  = "BeamPos"
s:Ge/DemoBox/Material                = "Air"
d:Ge/DemoBox/TransX                  = 0 cm
d:Ge/DemoBox/TransY                  = 0 cm
d:Ge/DemoBox/TransZ                  = 0 cm
d:Ge/DemoBox/RotX                    = 0 deg
d:Ge/DemoBox/RotY                    = 0 deg
d:Ge/DemoBox/RotZ                    = 0 deg
d:Ge/DemoBox/HLX                     = 15. mm
d:Ge/DemoBox/HLY                     = 15 mm
d:Ge/DemoBox/HLZ                     = 0.5 mm
s:Ge/DemoBox/Color                   = "transred"
s:Ge/DemoBox/DrawingStyle       = "solid"
#b:Ge/DemoBox/Invisible = "true"


# Source 1
s:So/Source1/Type = "Beam"
s:So/Source1/Component = "BeamPos"
s:So/Source1/BeamParticle = "e-"
d:So/Source1/BeamEnergy= 200 MeV
u:So/Source1/BeamEnergySpread = 0.0
s:So/Source1/BeamPositionDistribution = "Flat" # Flat, Gaussian or Twiss
s:So/Source1/BeamPositionCutoffShape = "Rectangle" # Ellipse or Rectangle
d:So/Source1/BeamPositionCutoffX = 1.5 cm
d:So/Source1/BeamPositionCutoffY = 1.5 cm
s:So/Source1/BeamAngularDistribution = "none"
d:So/Source1/BeamAngularCutoffX = 0 deg
d:So/Source1/BeamAngularCutoffY = 0 deg
d:So/Source1/BeamAngularSpreadX = 0.00 rad
d:So/Source1/BeamAngularSpreadY = 0.00 rad                                                                                                                                                                            
i:So/Source1/NumberOfHistoriesInRun = 1000000                                                                                                                                                                            
i:Ts/Seed ='''+str(randint(2,800000))+'''



# Overall program control
i:Ts/ShowHistoryCountAtInterval = 100 # How often to print history count to the console
b:Ts/ShowCPUTime = "True"
#Ts/ShowHistoryCountOnSingleLine = "True"
s:Ts/PauseForGeant4Commands = "Never"  #"Never" #"BeforeQuit" # Never or one or more of BeforeInit, BeforeSequence, BeforeQuit





#s:Sc/scorer/Parent = "Patient"
#s:Sc/scorer/Quantity                  = "DoseToMedium"
#s:Sc/scorer/Component                 = "Patient/RTDoseGrid"
#b:Sc/scorer/OutputToConsole           = "False"
#s:Sc/scorer/IfOutputFileAlreadyExists = "Overwrite"
#s:Sc/scorer/OutputType                = "dicom"
#s:Sc/scorer/OutputFile = "./results/best_dosetomedium_vhee_shapedopenbeam_200MV_1M_'''+str(j)+'''deg__'''+str(i)+'''"
#sv:Sc/scorer/Report = 1 "Sum"


#


sv:Ph/Default/LayeredMassGeometryWorlds=1 "Hole1"
s:Ge/Collimator/Type               = "TsCylinder"
s:Ge/Collimator/Parent             = "World"
s:Ge/Collimator/Material           = "W_EGS"
d:Ge/Collimator/TransX             = 215 mm # '''+str(11.644+215*np.cos(j*np.pi/180))+''' mm
d:Ge/Collimator/TransY             = 0 mm #'''+str(15.594+215*np.sin(j*np.pi/180))+''' mm
d:Ge/Collimator/TransZ             = 0 mm #-11.52 mm
d:Ge/Collimator/RotX               = 0 deg
d:Ge/Collimator/RotY               = 270 deg
d:Ge/Collimator/RotZ               = 0 deg
d:Ge/Collimator/RMax               = 25 mm
d:Ge/Collimator/HL                 = '''+str(30/2)+''' mm
d:Ge/Collimator/SPhi               = 0. rad
d:Ge/Collimator/DPhi               = 360 deg
s:Ge/Collimator/Color              = "transgrey"
s:Ge/Collimator/DrawingStyle       = "solid"
b:Ge/Collimator/Invisible = "true"

s:Ge/tumourcol/Type = "TsCAD"
s:Ge/tumourcol/Parent = "World"
s:Ge/tumourcol/Material = "W_EGS"
d:Ge/tumourcol/TransX= '''+str(11.644+180*np.cos(j*np.pi/180))+''' mm
d:Ge/tumourcol/TransY= '''+str(15.594+180*np.sin(j*np.pi/180))+''' mm
d:Ge/tumourcol/TransZ= -11.52 mm # was -8.7588 mm
d:Ge/tumourcol/RotX = 0.0 deg
d:Ge/tumourcol/RotY = 0.0 deg
d:Ge/tumourcol/RotZ = 180.0 deg
s:Ge/tumourcol/DrawingStyle = "Solid"
s:Ge/tumourcol/Color = "grey"
# CAD-specific parameters:
s:Ge/tumourcol/InputFile = "./1_rtstruct_anon_ptv-ov1_'''+str(j)+'''degCOL_3" # file name, without extensions. Match exact case
s:Ge/tumourcol/FileFormat = "stl" # file extension
d:Ge/tumourcol/Units = 1.0 mm # how to interpret dimension numbers in the file. Changing this value will re-scale the component
#b:Ge/tumourcol/Invisible = "true"

s:Ge/tumour/Type = "TsCAD"
s:Ge/tumour/Parent = "World"
s:Ge/tumour/Material = "W_EGS"
d:Ge/tumour/TransX= '''+str(11.644)+''' mm
d:Ge/tumour/TransY= '''+str(15.594)+''' mm
d:Ge/tumour/TransZ= -11.52 mm # was -8.7588 mm
d:Ge/tumour/RotX = 0.0 deg
d:Ge/tumour/RotY = 0.0 deg
d:Ge/tumour/RotZ = 180.0 deg
s:Ge/tumour/DrawingStyle = "Solid"
s:Ge/tumour/Color = "red"
# CAD-specific parameters:
s:Ge/tumour/InputFile = "./1 RTSTRUCT ANON_PTV-ov" # file name, without extensions. Match exact case
s:Ge/tumour/FileFormat = "stl" # file extension
d:Ge/tumour/Units = 1.0 mm # how to interpret dimension numbers in the file. Changing this value will re-scale the component
#b:Ge/tumour/Invisible = "true"

s:Ge/body/Type = "TsCAD"
s:Ge/body/Parent = "World"
s:Ge/body/Material = "W_EGS"
d:Ge/body/TransX= '''+str(-237.656)+''' mm
d:Ge/body/TransY= '''+str(-248.906)+''' mm
d:Ge/body/TransZ= 716.48 mm # was -8.7588 mm
d:Ge/body/RotX = 0.0 deg
d:Ge/body/RotY = 0.0 deg
d:Ge/body/RotZ = 180.0 deg
s:Ge/body/DrawingStyle = "Solid"
s:Ge/body/Color = "transgreen"
# CAD-specific parameters:
s:Ge/body/InputFile = "./1 RTSTRUCT ANON_BODY" # file name, without extensions. Match exact case
s:Ge/body/FileFormat = "stl" # file extension
d:Ge/body/Units = 1.0 mm # how to interpret dimension numbers in the file. Changing this value will re-scale the component
#b:Ge/body/Invisible = "true"

# The phantom
s:Ge/WaterPhantom/Parent = "World"
s:Ge/WaterPhantom/Type   = "TsBox"
s:Ge/WaterPhantom/Material = "G4_WATER"
d:Ge/WaterPhantom/HLX = 2.5 cm
d:Ge/WaterPhantom/HLY = 2.5 cm
d:Ge/WaterPhantom/HLZ = 5 cm
d:Ge/WaterPhantom/TransX =  0.0 cm
d:Ge/WaterPhantom/TransY =  0.0 cm
d:Ge/WaterPhantom/TransZ =  0 cm
d:Ge/WaterPhantom/RotX= 0. deg
d:Ge/WaterPhantom/RotY= 90. deg
d:Ge/WaterPhantom/RotZ= 0. deg
s:Ge/WaterPhantom/Color = "transwater"
s:Ge/WaterPhantom/DrawingStyle = "Solid"
b:Ge/WaterPhantom/Invisible = "true"
''')

#Everything in mm
#SCD=22
col_thick= 35
small_slit=0.5
big_slit=0.5
small_sep=1.1
big_sep= 1.1
HL_small=small_slit/2
HL_big=big_slit/2
x=big_sep+big_slit
#z=col_thick/2+SCD
holes=17
#angle=np.arctan(x/z)*180/np.pi
h=1
for j in np.arange(-(holes-1)/2*x,(holes-1)/2*x+x-0.001,x):
    for k in np.arange(-(holes-1)/2*x,(holes-1)/2*x+x-0.001,x):
        if j>=0:
            f.write('''

s:Ge/Hole'''+str(h)+'''/Type               = "G4GTrap"
b:Ge/Hole'''+str(h)+'''/IsParallel         = "True"
s:Ge/Hole'''+str(h)+'''/Parent             = "Collimator"
s:Ge/Hole'''+str(h)+'''/Material           = "Air"
d:Ge/Hole'''+str(h)+'''/TransX             = '''+str(j)+''' mm
d:Ge/Hole'''+str(h)+'''/TransY             = '''+str(k)+''' mm
d:Ge/Hole'''+str(h)+'''/TransZ             = 0 cm
d:Ge/Hole'''+str(h)+'''/RotX               = 0 deg
d:Ge/Hole'''+str(h)+'''/RotY               = 0 deg
d:Ge/Hole'''+str(h)+'''/RotZ               = 0 deg
d:Ge/Hole'''+str(h)+'''/HLY1                 = '''+str(HL_small)+''' mm
d:Ge/Hole'''+str(h)+'''/HLY2                 = '''+str(HL_big)+''' mm
d:Ge/Hole'''+str(h)+'''/HLX1                 = '''+str(HL_small)+''' mm
d:Ge/Hole'''+str(h)+'''/HLX2                 = '''+str(HL_small)+''' mm
d:Ge/Hole'''+str(h)+'''/HLX3                 = '''+str(HL_big)+''' mm
d:Ge/Hole'''+str(h)+'''/HLX4                 = '''+str(HL_big)+''' mm
d:Ge/Hole'''+str(h)+'''/HLZ                 = '''+str(col_thick/2)+''' mm
d:Ge/Hole'''+str(h)+'''/Theta                 = '''+str(0)+''' deg
d:Ge/Hole'''+str(h)+'''/Alp1                 = 0 deg
d:Ge/Hole'''+str(h)+'''/Alp2                 = 0 deg
d:Ge/Hole'''+str(h)+'''/Phi                 = '''+str(0)+''' deg
s:Ge/Hole'''+str(h)+'''/Color              = "white"
s:Ge/Hole'''+str(h)+'''/DrawingStyle       = "Solid"
s:Ge/Hole'''+str(h)+'''/ParallelWorldName  = "Hole1"
b:Ge/Hole'''+str(h)+'''/Invisible = "true"
''')
            h=h+1
        else:
            f.write('''

s:Ge/Hole'''+str(h)+'''/Type               = "G4GTrap"
b:Ge/Hole'''+str(h)+'''/IsParallel         = "True"
s:Ge/Hole'''+str(h)+'''/Parent             = "Collimator"
s:Ge/Hole'''+str(h)+'''/Material           = "Air"
d:Ge/Hole'''+str(h)+'''/TransX             = '''+str(j)+''' mm
d:Ge/Hole'''+str(h)+'''/TransY             = '''+str(k)+''' mm
d:Ge/Hole'''+str(h)+'''/TransZ             = 0 cm
d:Ge/Hole'''+str(h)+'''/RotX               = 0 deg
d:Ge/Hole'''+str(h)+'''/RotY               = 0 deg
d:Ge/Hole'''+str(h)+'''/RotZ               = 0 deg
d:Ge/Hole'''+str(h)+'''/HLY1                 = '''+str(HL_small)+''' mm
d:Ge/Hole'''+str(h)+'''/HLY2                 = '''+str(HL_big)+''' mm
d:Ge/Hole'''+str(h)+'''/HLX1                 = '''+str(HL_small)+''' mm
d:Ge/Hole'''+str(h)+'''/HLX2                 = '''+str(HL_small)+''' mm
d:Ge/Hole'''+str(h)+'''/HLX3                 = '''+str(HL_big)+''' mm
d:Ge/Hole'''+str(h)+'''/HLX4                 = '''+str(HL_big)+''' mm
d:Ge/Hole'''+str(h)+'''/HLZ                 = '''+str(col_thick/2)+''' mm
d:Ge/Hole'''+str(h)+'''/Theta                 = '''+str(0)+''' deg
d:Ge/Hole'''+str(h)+'''/Alp1                 = 0 deg
d:Ge/Hole'''+str(h)+'''/Alp2                 = 0 deg
d:Ge/Hole'''+str(h)+'''/Phi                 = '''+str(0)+''' deg
s:Ge/Hole'''+str(h)+'''/Color              = "white"
s:Ge/Hole'''+str(h)+'''/DrawingStyle       = "Solid"
s:Ge/Hole'''+str(h)+'''/ParallelWorldName  = "Hole1"

b:Ge/Hole'''+str(h)+'''/Invisible = "true"
''')





            h=h+1
#d:Ge/Hole'''+str(h)+'''/HLZ                 = '''+str(np.sqrt(z**2+(z*np.tan(j/x*angle*np.pi/180))**2++(z*np.tan(k/x*angle*np.pi/180))**2))+''' mm
f.close()
