# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import linregress
Ea=np.array([7.06692,6.71767,6.5502,5.9399,7.017])
T=np.array([18,420,3100,6900,60])
plt.plot(Ea**-0.5,np.log10(T))
linregress(Ea**-0.5,np.log10(T))
# Out:
# LinregressResult(slope=71.79224734288363, intercept=-25.26572661435827, rvalue=0.9019912890708356, pvalue=0.03628615596216014, stderr=19.840434463568602)
