# %%
import numpy as np
import tigre
import tigre.algorithms as algs
import matplotlib.pyplot as plt
from numpy import genfromtxt
from matplotlib.pyplot import figure
from skimage.transform import iradon
import matplotlib
import scipy as sp
from matplotlib.colors import LinearSegmentedColormap
import matplotlib
# %matplotlib inline

font = {'family' : 'Arial',
        'weight' : 'normal',
        'size'   : 20}
matplotlib.rc('font', **font)

#order is 5,3.3,3,2,1,0
tigre_I=[1,0.3111,0.3667,0.1915,0.1469,0]
tigre_Gd=[1,0.3007,0.3831,0.1210,0.1182,0.02516]
tigre_Au=[1,0.3148,0.5771,0.1825,0.1534,0.001333]

sair_I=[1,0.4509,0.4158,0.2657,0.1299,0.0223]
sair_Gd=[1,0.2752,0.3630,0.1022,0.1053,0.0151]
sair_Au=[1,0.4631,0.6949,0.3318,0.1888,0.03944]

czt_I=[1,0.6132,0.4495,0.3702,0.1910,0.0245]
czt_Gd=[1,0,0.4293,0,0.0076,0]
czt_Au=[1,0,0.5330,0,0.0233,0.0316]


x0=np.arange(0,9)
x1=[i+20 for i in x0]
x2=[i+40 for i in x0]
x3=[i+60 for i in x0]
x33=[i+80 for i in x0]
x5=[i+100 for i in x0]

masterx=[x5,x33,x3,x2,x1,x0]

c=['#ffcc00','darkviolet','limegreen']

figure(1,figsize=(14,9))
plt.grid(c='lightgray',alpha=0.7)
plt.bar([i[0] for i in masterx],tigre_Au,color='#ffcc00',hatch='x')
plt.bar([i[3] for i in masterx],tigre_Gd,color='limegreen',hatch='x')
plt.bar([i[6] for i in masterx],tigre_I,color='darkviolet',hatch='x')

plt.bar([i[1] for i in masterx],sair_Au,color='#ffcc00',hatch='.')
plt.bar([i[4] for i in masterx],sair_Gd,color='limegreen',hatch='.')
plt.bar([i[7] for i in masterx],sair_I,color='darkviolet',hatch='.')

plt.bar([i[2] for i in masterx],czt_Au,color='#ffcc00',hatch='/')
plt.bar([i[5] for i in masterx],czt_Gd,color='limegreen',hatch='/')
plt.bar([i[8] for i in masterx],czt_I,color='darkviolet',hatch='/')
plt.bar(20,0.00001,hatch='.',label='SAIR',color='lightgray')
plt.bar(21,0.000002,hatch='x',label='CdTe K-edge',color='lightgray')
plt.bar(22,0.00002,hatch='/',label='CZT K-edge',color='lightgray')
plt.legend()
plt.xticks([4.5,24.5,44.5,64.5,84.5,104.5], ['0','1','2','3','3.3','5'])


x0=np.arange(0,18,3)
x1=[i+1 for i in x0]
x1=np.array(x1)
x2=[i+2 for i in x0]
x2=np.array(x2)


figure(2,figsize=(14,9))
plt.grid(c='lightgray',alpha=0.7)
plt.bar(x0*-1,tigre_Au,color='#ffcc00',hatch='x')
plt.bar([-i-20 for i in x0],tigre_Gd,color='limegreen',hatch='x')
plt.bar([-i-40 for i in x0],tigre_I,color='darkviolet',hatch='x')

plt.bar(x1*-1,sair_Au,color='#ffcc00',hatch='.')
plt.bar([-i-20 for i in x1],sair_Gd,color='limegreen',hatch='.')
plt.bar([-i-40 for i in x1],sair_I,color='darkviolet',hatch='.')

plt.bar(-1*x2,czt_Au,color='#ffcc00',hatch='/')
plt.bar([-i-20 for i in x2],czt_Gd,color='limegreen',hatch='/')
plt.bar([-i-40 for i in x2],czt_I,color='darkviolet',hatch='/')
plt.bar(20,0.00001,hatch='.',label='SAIR',color='lightgray')
plt.bar(21,0.000002,hatch='x',label='CdTe K-edge',color='lightgray')
plt.bar(22,0.00002,hatch='/',label='CZT K-edge',color='lightgray')
plt.legend()
plt.xticks([-47.5,-27.5,-7.5], ['I','Gd','Au'])
# Out:
# ([<matplotlib.axis.XTick at 0x23d810ae748>,
# ...
#  <a list of 3 Text xticklabel objects>)
