# %%
import numpy as np 
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import matplotlib
from matplotlib.ticker import MaxNLocator

font = {'family' : 'Arial',
        'weight' : 'normal',
        'size'   : 18}

matplotlib.rc('font', **font)
def align_y_axis(ax1, ax2, minresax1, minresax2,numticks):
    """ Sets tick marks of twinx axes to line up with x total tick marks

    ax1 and ax2 are matplotlib axes
    Spacing between tick marks will be a factor of minresax1 and minresax2"""

    ax1ylims = ax1.get_ybound()
    ax2ylims = ax2.get_ybound()
    ax1factor = minresax1 * (numticks-1)
    ax2factor = minresax2 * (numticks-1)
    ax1.set_yticks(np.linspace(ax1ylims[0],
                               ax1ylims[1]+(ax1factor -
                               (ax1ylims[1]-ax1ylims[0]) % ax1factor) %
                               ax1factor,
                               numticks))
    ax2.set_yticks(np.linspace(ax2ylims[0],
                               ax2ylims[1]+(ax2factor -
                               (ax2ylims[1]-ax2ylims[0]) % ax2factor) %
                               ax2factor,
                               numticks))

# %%
colthick=[40,50,60,70,80,90]
smallslitsep=[0.301,0.4,0.5,0.6,0.7,0.8]
smallslit=[0.332,0.432,0.532,0.632,0.732,0.832]
focus=[52,42,32,22,12,8]


# thicopt2=np.load('Desktop/SFRT-Topas/thic_opt2/thicopt2.npy')
# thicopt2_5MV=np.load('Desktop/SFRT-Topas/thic_opt2_5MV/thicopt2_5MV.npy')
# holeopt2=np.load('Desktop/SFRT-Topas/hole_opt2/holeopt2.npy')
# holeopt2_5MV=np.load('Desktop/SFRT-Topas/hole_opt2_5MV/holeopt2_5MV.npy')
# sepopt2=np.load('Desktop/SFRT-Topas/sep_opt2/sepopt2.npy')
# sepopt2_5MV=np.load('Desktop/SFRT-Topas/sep_opt2_5MV/sepopt2_5MV.npy')
# divopt2=np.load('Desktop/SFRT-Topas/div_opt2/divopt2.npy')
# divopt2_5MV=np.load('Desktop/SFRT-Topas/div_opt2_5MV/divopt2_5MV.npy')



figure(1,figsize=(8,8))
fig, ax1=plt.subplots(figsize=(8,8))
plt.plot(colthick,thicopt2[1],marker='o',markersize=9,label='Mean peak dose rate 10 MV (Gy/s)',c='deepskyblue')
plt.plot(colthick,thicopt2_5MV[1],marker='d',markersize=9,label='Mean peak dose rate 5 MV (Gy/s)',c='deepskyblue',ls='--')
plt.plot(colthick,thicopt2_new[1],marker='o',markersize=9,label='Mean peak dose rate 10 MV (Gy/s)',c='green')
plt.plot(colthick,thicopt2_5MV_new[1],marker='d',markersize=9,label='Mean peak dose rate 5 MV (Gy/s)',c='green',ls='--')
plt.ylim(bottom=0,top=14)
plt.ylabel('Mean peak dose rate (Gy/s)',c='deepskyblue')
plt.xlabel('Collimator thickness (mm)')
plt.grid(c='lightgray',axis='both',ls='--')
ax2=ax1.twinx()
plt.plot(colthick,thicopt2[0],marker='o',markersize=9,label='PVDR 10 MV',c='mediumvioletred')
plt.plot(colthick,thicopt2_5MV[0],marker='d',markersize=9,label='PVDR 5 MV',c='mediumvioletred',ls='--')
plt.plot(colthick,thicopt2_new[0],marker='o',markersize=9,label='PVDR 10 MV',c='orange')
plt.plot(colthick,thicopt2_5MV_new[0],marker='d',markersize=9,label='PVDR 5 MV',c='orange',ls='--')
plt.ylim(bottom=0,top=6)
plt.ylabel('PVDR',c='mediumvioletred')
plt.grid(c='lightgray',axis='both',ls='--')
#fig.legend(loc="upper center", bbox_to_anchor=(0.5,0.8455))

align_y_axis(ax1,ax2,0.5,0.25,7)

figure(2,figsize=(8,8))
fig, ax1=plt.subplots(figsize=(8,8))
plt.plot(focus,divopt2[1],marker='o',markersize=9,label='Mean peak dose rate 10 MV (Gy/s)',c='deepskyblue')
plt.plot(focus,divopt2_5MV[1],marker='d',markersize=9,label='Mean peak dose rate 5 MV (Gy/s)',c='deepskyblue',ls='--')
plt.plot(focus,divopt2_new[1],marker='o',markersize=9,label='Mean peak dose rate 10 MV (Gy/s)',c='green')
plt.plot(focus,divopt2_5MV_new[1],marker='d',markersize=9,label='Mean peak dose rate 5 MV (Gy/s)',c='green',ls='--')
plt.ylim(bottom=0,top=14)
plt.ylabel('Mean peak dose rate (Gy/s)',c='deepskyblue')
plt.xlabel('Virtual SCD (collimator focus) (mm)')
plt.grid(c='lightgray',axis='both',ls='--')
ax2=ax1.twinx()
plt.plot(focus,divopt2[0],marker='o',markersize=9,label='PVDR 10 MV',c='mediumvioletred')
plt.plot(focus,divopt2_5MV[0],marker='d',markersize=9,label='PVDR 5 MV',c='mediumvioletred',ls='--')
plt.plot(focus,divopt2_new[0],marker='o',markersize=9,label='PVDR 10 MV',c='orange')
plt.plot(focus,divopt2_5MV_new[0],marker='d',markersize=9,label='PVDR 5 MV',c='orange',ls='--')
plt.ylim(bottom=0,top=6)
plt.ylabel('PVDR',c='mediumvioletred')
plt.grid(c='lightgray',axis='both',ls='--')
#fig.legend(loc="upper center", bbox_to_anchor=(0.5,0.8455))

align_y_axis(ax1,ax2,0.5,0.25,7)


figure(3,figsize=(8,8))
fig, ax1=plt.subplots(figsize=(8,8))
plt.plot(smallslitsep,sepopt2[1],marker='o',markersize=9,label='Mean peak dose rate 10 MV (Gy/s)',c='deepskyblue')
plt.plot(smallslitsep,sepopt2_5MV[1],marker='d',markersize=9,label='Mean peak dose rate 5 MV (Gy/s)',c='deepskyblue',ls='--')
plt.plot(smallslitsep,sepopt2_new[1],marker='o',markersize=9,label='Mean peak dose rate 10 MV (Gy/s)',c='green')
plt.plot(smallslitsep,sepopt2_5MV_new[1],marker='d',markersize=9,label='Mean peak dose rate 5 MV (Gy/s)',c='green',ls='--')
plt.ylim(bottom=0,top=14)
plt.ylabel('Mean peak dose rate (Gy/s)',c='deepskyblue')
plt.xlabel('Septal width [source side] (mm)')
plt.grid(c='lightgray',axis='both',ls='--')
ax2=ax1.twinx()
plt.plot(smallslitsep,sepopt2[0],marker='o',markersize=9,label='PVDR 10 MV',c='mediumvioletred')
plt.plot(smallslitsep,sepopt2_5MV[0],marker='d',markersize=9,label='PVDR 5 MV',c='mediumvioletred',ls='--')
plt.plot(smallslitsep,sepopt2_new[0],marker='o',markersize=9,label='PVDR 10 MV',c='orange')
plt.plot(smallslitsep,sepopt2_5MV_new[0],marker='d',markersize=9,label='PVDR 5 MV',c='orange',ls='--')
plt.ylim(bottom=0,top=6)
plt.ylabel('PVDR',c='mediumvioletred')
plt.grid(c='lightgray',axis='both',ls='--')
#fig.legend(loc="upper center", bbox_to_anchor=(0.5,0.8455))

align_y_axis(ax1,ax2,0.5,0.25,7)

figure(4,figsize=(8,8))
fig, ax1=plt.subplots(figsize=(8,8))
plt.plot(smallslit,holeopt2[1],marker='o',markersize=9,label='Mean peak dose rate 10 MV (Gy/s)',c='deepskyblue')
plt.plot(smallslit,holeopt2_5MV[1],marker='d',markersize=9,label='Mean peak dose rate 5 MV (Gy/s)',c='deepskyblue',ls='--')
plt.plot(smallslit,holeopt2_new[1],marker='o',markersize=9,label='Mean peak dose rate 10 MV (Gy/s)',c='green')
plt.plot(smallslit,holeopt2_5MV_new[1],marker='d',markersize=9,label='Mean peak dose rate 5 MV (Gy/s)',c='green',ls='--')
plt.ylim(bottom=0,top=14)
plt.ylabel('Mean peak dose rate (Gy/s)',c='deepskyblue')
plt.xlabel('Hole width [source side] (mm)')
plt.grid(c='lightgray',axis='both',ls='--')
ax2=ax1.twinx()
plt.plot(smallslit,holeopt2[0],marker='o',markersize=9,label='PVDR 10 MV',c='mediumvioletred')
plt.plot(smallslit,holeopt2_5MV[0],marker='d',markersize=9,label='PVDR 5 MV',c='mediumvioletred',ls='--')
plt.plot(smallslit,holeopt2_new[0],marker='o',markersize=9,label='PVDR 10 MV',c='orange')
plt.plot(smallslit,holeopt2_5MV_new[0],marker='d',markersize=9,label='PVDR 5 MV',c='orange',ls='--')
plt.ylim(bottom=0,top=6)
plt.ylabel('PVDR',c='mediumvioletred')
plt.grid(c='lightgray',axis='both',ls='--')
#fig.legend(loc="upper center", bbox_to_anchor=(0.5,0.8455))

align_y_axis(ax1,ax2,0.5,0.25,7)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-f6c8b63015bf> in <module>
#      16
#      17
# ---> 18 figure(1,figsize=(8,8))
#      19 fig, ax1=plt.subplots(figsize=(8,8))
#      20 plt.plot(colthick,thicopt2[1],marker='o',markersize=9,label='Mean peak dose rate 10 MV (Gy/s)',c='deepskyblue')
#
# NameError: name 'figure' is not defined

# %%
colthick=[40,50,60,70,80,90]
smallslitsep=[0.301,0.4,0.5,0.6,0.7,0.8]
smallslit=[0.332,0.432,0.532,0.632,0.732,0.832]
focus=[42,32,22,12]


thicopt2_new=np.load('D:Desktop/SFRT-Topas/thic_opt2/thicopt2_new.npy')
thicopt2_5MV_new=np.load('D:Desktop/SFRT-Topas/thic_opt2_5MV/thicopt2_5MV_new.npy')
holeopt2_new=np.load('D:Desktop/SFRT-Topas/hole_opt2/holeopt2_new.npy')
holeopt2_5MV_new=np.load('D:Desktop/SFRT-Topas/hole_opt2_5MV/holeopt2_5MV_new.npy')
sepopt2_new=np.load('D:Desktop/SFRT-Topas/sep_opt2/sepopt2_new.npy')
sepopt2_5MV_new=np.load('D:Desktop/SFRT-Topas/sep_opt2_5MV/sepopt2_5MV_new.npy')
divopt2_new=np.load('D:Desktop/SFRT-Topas/div_opt2/divopt2_new.npy')
divopt2_5MV_new=np.load('D:Desktop/SFRT-Topas/div_opt2_5MV/divopt2_5MV_new.npy')
holeopt2_1MV=np.load('D:Desktop/SFRT-Topas/hole_opt2_1MV/holeopt2_1MV.npy')
thicopt2_1MV=np.load('D:Desktop/SFRT-Topas/thic_opt2_1MV/thicopt2_1MV.npy')
sepopt2_1MV=np.load('D:Desktop/SFRT-Topas/sep_opt2_1MV/sepopt2_1MV.npy')
divopt2_1MV=np.load('D:Desktop/SFRT-Topas/div_opt2_1MV/divopt2_1MV.npy')
print(holeopt2_5MV_new[3])

#ADJUSTING CURRENTS FOR 1 kW HERE DONT CHANGE IT ELSEWHERE ___________________________________________________________
thicopt2_5MV_new[1]= thicopt2_5MV_new[1]*2
sepopt2_5MV_new[1]= sepopt2_5MV_new[1]*2
holeopt2_5MV_new[1]= holeopt2_5MV_new[1]*2
divopt2_5MV_new[1]= divopt2_5MV_new[1]*2

thicopt2_1MV[1]= thicopt2_1MV[1]*10
sepopt2_1MV[1]= sepopt2_1MV[1]*10
holeopt2_1MV[1]= holeopt2_1MV[1]*10
divopt2_1MV[1]= divopt2_1MV[1]*10



figure(1,figsize=(8,8))
fig, ax1=plt.subplots(figsize=(8,8))
plt.errorbar(colthick,thicopt2_new[1],yerr=thicopt2_new[2],marker='o',markersize=10,capsize=6,c='tab:blue',ls='--')
plt.errorbar(colthick,thicopt2_5MV_new[1],yerr=thicopt2_5MV_new[2],marker='d',markersize=10,capsize=6,c='tab:blue',ls='--')
plt.errorbar(colthick,thicopt2_1MV[1],yerr=thicopt2_1MV[2],marker='s',markersize=10,capsize=6,c='tab:blue',ls='--')
#plt.ylim(bottom=0.05,top=15)
plt.ylabel('Mean peak dose rate (Gy/s)',c='tab:blue')
plt.xlabel('Collimator thickness (mm)')
plt.grid(c='lightgray',axis='both')
plt.yscale("log")
ax1.set_yticks([0.01,0.1,1, 5, 15])
ax1.get_yaxis().set_major_formatter(matplotlib.ticker.FixedFormatter([0.01,0.1,1, 5, 15]))
ax2=ax1.twinx()
plt.errorbar(colthick,thicopt2_new[0],yerr=thicopt2_new[3],marker='o',markersize=10,capsize=6,label='10 MV',c='tab:orange')
plt.errorbar(colthick,thicopt2_5MV_new[0],yerr=thicopt2_5MV_new[3],marker='d',markersize=10,capsize=6,label='5 MV',c='tab:orange')
plt.errorbar(colthick,thicopt2_1MV[0],marker='s',yerr=thicopt2_1MV[3],markersize=10,capsize=6,label='1 MV',c='tab:orange')
#plt.ylim(bottom=0,top=100)
plt.ylabel('PVDR',c='tab:orange')
plt.grid(c='lightgray',axis='both')
plt.yscale("log")
ax2.set_yticks([1,5,10, 50, 100])
ax2.get_yaxis().set_major_formatter(matplotlib.ticker.FixedFormatter([1,5,10, 50, 100]))
#fig.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

#align_y_axis(ax1,ax2,0.01,1,5)

figure(2,figsize=(8,8))
fig, ax1=plt.subplots(figsize=(8,8))
plt.errorbar(focus,divopt2_new[1],yerr=divopt2_new[2],marker='o',markersize=10,capsize=6,label='Mean peak dose rate 10 MV (Gy/s)',c='tab:blue',ls='--')
plt.errorbar(focus,divopt2_5MV_new[1],yerr=divopt2_5MV_new[2],marker='d',markersize=10,capsize=6,label='Mean peak dose rate 5 MV (Gy/s)',c='tab:blue',ls='--')
plt.errorbar(focus,divopt2_1MV[1],yerr=divopt2_1MV[2],marker='s',markersize=10,capsize=6,label='Mean peak dose rate 1 MV (Gy/s)',c='tab:blue',ls='--')
#plt.ylim(bottom=0,top=14)
plt.ylabel('Mean peak dose rate (Gy/s)',c='tab:blue')
plt.xlabel('Focus position (mm)')
plt.grid(c='lightgray',axis='both')
plt.yscale("log")
ax1.set_yticks([0.01,0.1,1,5, 10])
ax1.get_yaxis().set_major_formatter(matplotlib.ticker.FixedFormatter([0.01,0.1,1,5, 10]))
ax2=ax1.twinx()
plt.errorbar(focus,divopt2_new[0],yerr=divopt2_new[3],marker='o',markersize=10,capsize=6,capthick=3,label='PVDR 10 MV',c='tab:orange')
plt.errorbar(focus,divopt2_5MV_new[0],yerr=divopt2_5MV_new[3],marker='d',markersize=10,capsize=6,label='PVDR 5 MV',c='tab:orange')
plt.errorbar(focus,divopt2_1MV[0],yerr=divopt2_1MV[3],marker='s',markersize=10,capsize=6,label='PVDR 1 MV',c='tab:orange')
#plt.ylim(bottom=0,top=6)
plt.ylabel('PVDR',c='tab:orange')
plt.grid(c='lightgray',axis='both')
plt.yscale("log")
ax2.set_yticks([1,2, 5,10,20])
ax2.get_yaxis().set_major_formatter(matplotlib.ticker.FixedFormatter([1,2, 5,10,20]))
#fig.legend(loc="upper center", bbox_to_anchor=(0.5,0.8455))

#align_y_axis(ax1,ax2,10,10,7)


figure(3,figsize=(8,8))
fig, ax1=plt.subplots(figsize=(8,8))
plt.errorbar(smallslitsep,sepopt2_new[1],yerr=sepopt2_new[2],marker='o',markersize=10,capsize=6,label='Mean peak dose rate 10 MV (Gy/s)',c='tab:blue',ls='--')
plt.errorbar(smallslitsep,sepopt2_5MV_new[1],yerr=sepopt2_5MV_new[2],marker='d',markersize=10,capsize=6,label='Mean peak dose rate 5 MV (Gy/s)',c='tab:blue',ls='--')
plt.errorbar(smallslitsep,sepopt2_1MV[1],yerr=sepopt2_1MV[2],marker='s',markersize=10,capsize=6,label='Mean peak dose rate 1 MV (Gy/s)',c='tab:blue',ls='--')
#plt.ylim(bottom=0,top=14)
plt.ylabel('Mean peak dose rate (Gy/s)',c='tab:blue')
plt.xlabel('Septal width [source side] (mm)')
plt.grid(c='lightgray',axis='both')
plt.yscale("log")
ax1.set_yticks([0.01,0.1,1, 5, 10])
ax1.get_yaxis().set_major_formatter(matplotlib.ticker.FixedFormatter([0.01,0.1,1, 5, 10]))
ax2=ax1.twinx()
plt.errorbar(smallslitsep,sepopt2_new[0],yerr=sepopt2_new[3],marker='o',markersize=10,capsize=6,capthick=3,label='PVDR 10 MV',c='tab:orange')
plt.errorbar(smallslitsep,sepopt2_5MV_new[0],yerr=sepopt2_5MV_new[3],marker='d',markersize=10,capsize=6,label='PVDR 5 MV',c='tab:orange')
plt.errorbar(smallslitsep,sepopt2_1MV[0],yerr=sepopt2_1MV[3],marker='s',markersize=10,capsize=6,label='PVDR 1 MV',c='tab:orange')
#plt.ylim(bottom=0,top=6)
plt.ylabel('PVDR',c='tab:orange')
plt.grid(c='lightgray',axis='both')
plt.yscale("log")
ax2.set_yticks([1,2.5, 10,15,25])
ax2.get_yaxis().set_major_formatter(matplotlib.ticker.FixedFormatter([1,5, 10,15,25]))
#fig.legend(loc="upper center", bbox_to_anchor=(0.5,0.8455))

#align_y_axis(ax1,ax2,0.5,0.25,7)

figure(4,figsize=(8,8))
fig, ax1=plt.subplots(figsize=(8,8))
plt.errorbar(smallslit,holeopt2_new[1],yerr=holeopt2_new[2],marker='o',markersize=10,capsize=6,label='Mean peak dose rate 10 MV (Gy/s)',c='tab:blue',ls='--')
plt.errorbar(smallslit,holeopt2_5MV_new[1],yerr=holeopt2_5MV_new[2],marker='d',markersize=10,capsize=6,label='Mean peak dose rate 5 MV (Gy/s)',c='tab:blue',ls='--')
plt.errorbar(smallslit,holeopt2_1MV[1],yerr=holeopt2_1MV[2],marker='s',markersize=10,capsize=6,label='Mean peak dose rate 1 MV (Gy/s)',c='tab:blue',ls='--')
#plt.ylim(bottom=0,top=14)
plt.ylabel('Mean peak dose rate (Gy/s)',c='tab:blue')
plt.xlabel('Hole width [source side] (mm)')
plt.grid(c='lightgray',axis='both')
plt.yscale("log")
ax1.set_yticks([0.01,0.1,1, 5, 15])
ax1.get_yaxis().set_major_formatter(matplotlib.ticker.FixedFormatter([0.01,0.1,1, 5, 15]))
ax2=ax1.twinx()
plt.errorbar(smallslit,holeopt2_new[0],yerr=holeopt2_new[3],marker='o',markersize=10,capsize=6,capthick=3,label='PVDR 10 MV',c='tab:orange')
plt.errorbar(smallslit,holeopt2_5MV_new[0],yerr=holeopt2_5MV_new[3],marker='d',markersize=10,capsize=6,label='PVDR 5 MV',c='tab:orange')
plt.errorbar(smallslit,holeopt2_1MV[0],yerr=holeopt2_1MV[3],marker='s',markersize=10,capsize=6,label='PVDR 1 MV',c='tab:orange')
#plt.ylim(bottom=0,top=6)
plt.ylabel('PVDR',c='tab:orange')
plt.grid(c='lightgray',axis='both')
plt.yscale("log")
ax2.set_yticks([1, 2.5,5,7.5, 10])
ax2.get_yaxis().set_major_formatter(matplotlib.ticker.FixedFormatter([1, 3,5,7, 10]))
#fig.legend(loc="upper center", bbox_to_anchor=(0.5,0.8455))

#align_y_axis(ax1,ax2,0.5,0.25,7)
print((sepopt2_1MV[2]/sepopt2_1MV[1])*100)
# Out:
# [0.07026142 0.07647637 0.07482529 0.07941188 0.08636224 0.08956371]
# [0.36981601 0.35739374 0.36336065 0.32930641 0.34977781 0.33794352]

# %%
holeopt2_1MV=np.load('Desktop/SFRT-Topas/hole_opt2_5MV/holeopt2_1MV.npy')
thicopt2_1MV=np.load('Desktop/SFRT-Topas/thic_opt2_5MV/thicopt2_1MV.npy')
sepopt2_1MV=np.load('Desktop/SFRT-Topas/sep_opt2_5MV/sepopt2_1MV.npy')
divopt2_1MV=np.load('Desktop/SFRT-Topas/div_opt2_5MV/divopt2_1MV.npy')
