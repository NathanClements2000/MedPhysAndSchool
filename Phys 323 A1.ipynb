# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(1)
x = [44, 44, 46, 48, 48, 50, 50, 50, 53, 55, 55, 57, 57, 57, 57, 57, 59, 62, 62, 62, 62, 62, 64, 64, 64, 66, 66, 66, 68, 68, 71, 71, 71, 77, 80, 82, 86, 89, 91, 96, 100]
plt.title('Histogram of Grades')
plt.hist(x,bins=12,range=[40,100])

a=[0,-4.351]
b=[0,-1.150]
c=[0,0.357]
d=[0,2.069]
e=[0,-3.994]
f=[0,0.919]
xaxis= np.linspace(-5,5)
zeroarray= xaxis*0
plt.figure(2)
plt.plot(xaxis,zeroarray,color='black')
plt.plot(zeroarray,xaxis,color='black')
plt.plot(a,b,label='a',marker='o')
plt.plot(c,d,label='b',marker='o')
plt.plot(e,f,label='a+b',marker='o')
plt.plot(0,0,color='black',marker='o') 
plt.title('Complex Number Addition')
plt.xlabel('Real')
plt.ylabel('Imaginary')
plt.legend()
