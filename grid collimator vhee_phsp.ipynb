# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import matplotlib
from scipy.signal import argrelextrema
from random import randint

for i in np.arange(100,250+1,10):
    g = open("D:Desktop/SFRT-Topas/vhee/phsp/gridCollimator_vhee_phsp_"+str(i)+".txt", "w")
    g2 = open("D:Desktop/SFRT-Topas/vhee/phsp/moreholes_phsp__"+str(i)+".txt", "w")
    g3 = open("D:Desktop/SFRT-Topas/vhee/phsp/moreholes2_phsp__"+str(i)+".txt", "w")
    g4 = open("D:Desktop/SFRT-Topas/vhee/phsp/moreholes3_phsp__"+str(i)+".txt", "w")
    g5 = open("D:Desktop/SFRT-Topas/vhee/phsp/moreholes4_phsp__"+str(i)+".txt", "w")
    g6 = open("D:Desktop/SFRT-Topas/vhee/phsp/moreholes5_phsp__"+str(i)+".txt", "w")
    g7 = open("D:Desktop/SFRT-Topas/vhee/phsp/moreholes6_phsp__"+str(i)+".txt", "w")
    g8 = open("D:Desktop/SFRT-Topas/vhee/phsp/moreholes7_phsp__"+str(i)+".txt", "w")
    g9 = open("D:Desktop/SFRT-Topas/vhee/phsp/moreholes8_phsp__"+str(i)+".txt", "w")
    g9.write("includeFile = ./graphics_settings.txt")
    g2.write('''includeFile = ./moreholes2_phsp__'''+str(i)+'''.txt''')
    g3.write('''includeFile = ./moreholes3_phsp__'''+str(i)+'''.txt''')
    g4.write('''includeFile = ./moreholes4_phsp__'''+str(i)+'''.txt''')
    g5.write('''includeFile = ./moreholes5_phsp__'''+str(i)+'''.txt''')
    g6.write('''includeFile = ./moreholes6_phsp__'''+str(i)+'''.txt''')
    g7.write('''includeFile = ./moreholes7_phsp__'''+str(i)+'''.txt''')
    g8.write('''includeFile = ./moreholes8_phsp__'''+str(i)+'''.txt''')
    g.write('''includeFile = ./moreholes_phsp__'''+str(i)+'''.txt

sv:Ph/Default/LayeredMassGeometryWorlds=1 "Hole1"

sv:Ma/W_EGS/Components = 1 "Tungsten"
uv:Ma/W_EGS/Fractions = 1 1.0
d:Ma/W_EGS/Density = 19.3 g/cm3 #per EGSnrc PEGS4 data used by Chris or use 19.25
s:Ma/W_EGS/DefaultColor="Brown"
i:Ma/W_EGS/AtomicNumber = 74
d:Ma/W_EGS/AtomicMass = 183.85 g/mole #or 183.84 (ICRU 2016 value)


s:Ge/Collimator/Type               = "TsCylinder"
s:Ge/Collimator/Parent             = "World"
s:Ge/Collimator/Material           = "W_EGS"
d:Ge/Collimator/TransX             = 0 cm
d:Ge/Collimator/TransY             = 0 cm
d:Ge/Collimator/TransZ             = '''+str(30/2)+''' mm
d:Ge/Collimator/RotX               = 0 deg
d:Ge/Collimator/RotY               = 0 deg
d:Ge/Collimator/RotZ               = 0 deg
d:Ge/Collimator/RMax               = 25 mm
d:Ge/Collimator/HL                 = '''+str(30/2)+''' mm
d:Ge/Collimator/SPhi               = 0. rad
d:Ge/Collimator/DPhi               = 360 deg
s:Ge/Collimator/Color              = "transgrey"
s:Ge/Collimator/DrawingStyle       = "solid"

#Old general 

#Physics
sv:Ph/Default/Modules = 1 "g4em-standard_opt4" 
d:Ph/Default/CutforAllParticles= 0.01 cm


# Geometry
Ge/World/HLX=2.0 m
Ge/World/HLY=2.0 m
Ge/World/HLZ=2.0 m
b:Ge/World/Invisible = "true"
#s:Ge/World/Material = "Vacuum"
s:Ge/World/Material = "Air"
s:Ge/World/Color = "white"

s:Ge/BeamPosition/Parent="World"
s:Ge/BeamPosition/Type="Group"
d:Ge/BeamPosition/TransX=0. m
d:Ge/BeamPosition/TransY=0. m
d:Ge/BeamPosition/TransZ= -1.0 cm
d:Ge/BeamPosition/RotX=0. deg
d:Ge/BeamPosition/RotY=0. deg
d:Ge/BeamPosition/RotZ=0. deg



#
s:So/Source1/Type = "Beam"
s:So/Source1/Component = "BeamPosition"
s:So/Source1/BeamParticle = "e-"
d:So/Source1/BeamEnergy= '''+str(i)+''' MeV
u:So/Source1/BeamEnergySpread = 0.0
s:So/Source1/BeamPositionDistribution = "Flat" # Flat, Gaussian or Twiss
s:So/Source1/BeamPositionCutoffShape = "Rectangle" # Ellipse or Rectangle
d:So/Source1/BeamPositionCutoffX = 1.5 cm
d:So/Source1/BeamPositionCutoffY = 1.5 cm
s:So/Source1/BeamAngularDistribution = "none"
d:So/Source1/BeamAngularCutoffX = 0 deg
d:So/Source1/BeamAngularCutoffY = 0 deg
d:So/Source1/BeamAngularSpreadX = 0.00 rad
d:So/Source1/BeamAngularSpreadY = 0.00 rad
i:So/Source1/NumberOfHistoriesInRun = 5000000    

s:Ge/VacFilm/Type     = "TsBox"
s:Ge/VacFilm/Parent   = "World"
s:Ge/VacFilm/Material = "air"
d:Ge/VacFilm/HLX      = 2.5 cm
d:Ge/VacFilm/HLY      = 2.5 cm
d:Ge/VacFilm/HLZ      = 0.001 cm
d:Ge/VacFilm/TransX   = 0. cm
d:Ge/VacFilm/TransY   = 0. cm
d:Ge/VacFilm/TransZ   = 3.001 cm
d:Ge/VacFilm/RotX     = 0. deg
d:Ge/VacFilm/RotY     = 0. deg
d:Ge/VacFilm/RotZ     = 0. deg
s:Ge/VacFilm/Color    = "skyblue"

s:Sc/PhaseSpaceAtphspplane/Quantity                    = "PhaseSpace"
b:Sc/PhaseSpaceAtphspplane/OutputToConsole             = "True"
s:Sc/PhaseSpaceAtphspplane/Surface                     = "VacFilm/ZPlusSurface"
s:Sc/PhaseSpaceAtphspplane/OutputType                  = "Binary" # ASCII, Binary, Limited or ROOT
s:Sc/PhaseSpaceAtphspplane/OutputFile                  = "./results/BinaryPhspVHEE_'''+str(i)+'''"
b:Sc/PhaseSpaceAtphspplane/IncludeTOPASTime            = "True"
b:Sc/PhaseSpaceAtphspplane/IncludeTimeOfFlight         = "True"
b:Sc/PhaseSpaceAtphspplane/IncludeRunID                = "True"
b:Sc/PhaseSpaceAtphspplane/IncludeEventID              = "True"
b:Sc/PhaseSpaceAtphspplane/IncludeTrackID              = "True"
b:Sc/PhaseSpaceAtphspplane/IncludeParentID             = "True"
b:Sc/PhaseSpaceAtphspplane/IncludeVertexInfo           = "True"
b:Sc/PhaseSpaceAtphspplane/IncludeSeed                 = "True"
s:Sc/PhaseSpaceAtphspplane/IfOutputFileAlreadyExists   = "Overwrite"


# Overall program control
i:Ts/ShowHistoryCountAtInterval = 100 # How often to print history count to the console
b:Ts/ShowCPUTime = "True"
#Ts/ShowHistoryCountOnSingleLine = "True"
s:Ts/PauseForGeant4Commands = "Never"  #"Never" #"BeforeQuit" # Never or one or more of BeforeInit, BeforeSequence, BeforeQuit



''')


    #Everything in mm
    #SCD=22
    col_thick= 30
    small_slit=0.5
    big_slit=0.5
    small_sep=1.1
    big_sep= 1.1
    HL_small=small_slit/2
    HL_big=big_slit/2
    x=big_sep+big_slit
    #z=col_thick/2+SCD
    holes=17
    #angle=np.arctan(x/z)*180/np.pi
    h=1
    for j in np.arange(-(holes-1)/2*x,(holes-1)/2*x+x-0.001,x):
        for k in np.arange(-(holes-1)/2*x,(holes-1)/2*x+x-0.001,x):
            if ((j>=0) and (h>280)):
                g9.write('''

s:Ge/Hole'''+str(h)+'''/Type               = "G4GTrap"
b:Ge/Hole'''+str(h)+'''/IsParallel         = "True"
s:Ge/Hole'''+str(h)+'''/Parent             = "Collimator"
s:Ge/Hole'''+str(h)+'''/Material           = "Air"
d:Ge/Hole'''+str(h)+'''/TransX             = '''+str(np.around(j,3))+''' mm
d:Ge/Hole'''+str(h)+'''/TransY             = '''+str(np.around(k,3))+''' mm
d:Ge/Hole'''+str(h)+'''/TransZ             = 0 cm
d:Ge/Hole'''+str(h)+'''/RotX               = 0 deg
d:Ge/Hole'''+str(h)+'''/RotY               = 0 deg
d:Ge/Hole'''+str(h)+'''/RotZ               = 0 deg
d:Ge/Hole'''+str(h)+'''/HLY1                 = '''+str(HL_small)+''' mm
d:Ge/Hole'''+str(h)+'''/HLY2                 = '''+str(HL_big)+''' mm
d:Ge/Hole'''+str(h)+'''/HLX1                 = '''+str(HL_small)+''' mm
d:Ge/Hole'''+str(h)+'''/HLX2                 = '''+str(HL_small)+''' mm
d:Ge/Hole'''+str(h)+'''/HLX3                 = '''+str(HL_big)+''' mm
d:Ge/Hole'''+str(h)+'''/HLX4                 = '''+str(HL_big)+''' mm
d:Ge/Hole'''+str(h)+'''/HLZ                 = '''+str(col_thick/2)+''' mm
d:Ge/Hole'''+str(h)+'''/Theta                 = '''+str(0)+''' deg
d:Ge/Hole'''+str(h)+'''/Alp1                 = 0 deg
d:Ge/Hole'''+str(h)+'''/Alp2                 = 0 deg
d:Ge/Hole'''+str(h)+'''/Phi                 = '''+str(0)+''' deg
s:Ge/Hole'''+str(h)+'''/Color              = "white"
s:Ge/Hole'''+str(h)+'''/DrawingStyle       = "Solid"
s:Ge/Hole'''+str(h)+'''/ParallelWorldName  = "Hole1"
    ''')
                h=h+1
            if ((j<0) and (h>280)):
                g9.write('''

s:Ge/Hole'''+str(h)+'''/Type               = "G4GTrap"
b:Ge/Hole'''+str(h)+'''/IsParallel         = "True"
s:Ge/Hole'''+str(h)+'''/Parent             = "Collimator"
s:Ge/Hole'''+str(h)+'''/Material           = "Air"
d:Ge/Hole'''+str(h)+'''/TransX             = '''+str(np.around(j,3))+''' mm
d:Ge/Hole'''+str(h)+'''/TransY             = '''+str(np.around(k,3))+''' mm
d:Ge/Hole'''+str(h)+'''/TransZ             = 0 cm
d:Ge/Hole'''+str(h)+'''/RotX               = 0 deg
d:Ge/Hole'''+str(h)+'''/RotY               = 0 deg
d:Ge/Hole'''+str(h)+'''/RotZ               = 0 deg
d:Ge/Hole'''+str(h)+'''/HLY1                 = '''+str(HL_small)+''' mm
d:Ge/Hole'''+str(h)+'''/HLY2                 = '''+str(HL_big)+''' mm
d:Ge/Hole'''+str(h)+'''/HLX1                 = '''+str(HL_small)+''' mm
d:Ge/Hole'''+str(h)+'''/HLX2                 = '''+str(HL_small)+''' mm
d:Ge/Hole'''+str(h)+'''/HLX3                 = '''+str(HL_big)+''' mm
d:Ge/Hole'''+str(h)+'''/HLX4                 = '''+str(HL_big)+''' mm
d:Ge/Hole'''+str(h)+'''/HLZ                 = '''+str(col_thick/2)+''' mm
d:Ge/Hole'''+str(h)+'''/Theta                 = '''+str(0)+''' deg
d:Ge/Hole'''+str(h)+'''/Alp1                 = 0 deg
d:Ge/Hole'''+str(h)+'''/Alp2                 = 0 deg
d:Ge/Hole'''+str(h)+'''/Phi                 = '''+str(0)+''' deg
s:Ge/Hole'''+str(h)+'''/Color              = "white"
s:Ge/Hole'''+str(h)+'''/DrawingStyle       = "Solid"
s:Ge/Hole'''+str(h)+'''/ParallelWorldName  = "Hole1"
    ''')

                h=h+1
            if ((j>=0) and (h<=280) and (h>245) ):
                
                g8.write('''

s:Ge/Hole'''+str(h)+'''/Type               = "G4GTrap"
b:Ge/Hole'''+str(h)+'''/IsParallel         = "True"
s:Ge/Hole'''+str(h)+'''/Parent             = "Collimator"
s:Ge/Hole'''+str(h)+'''/Material           = "Air"
d:Ge/Hole'''+str(h)+'''/TransX             = '''+str(np.around(j,3))+''' mm
d:Ge/Hole'''+str(h)+'''/TransY             = '''+str(np.around(k,3))+''' mm
d:Ge/Hole'''+str(h)+'''/TransZ             = 0 cm
d:Ge/Hole'''+str(h)+'''/RotX               = 0 deg
d:Ge/Hole'''+str(h)+'''/RotY               = 0 deg
d:Ge/Hole'''+str(h)+'''/RotZ               = 0 deg
d:Ge/Hole'''+str(h)+'''/HLY1                 = '''+str(HL_small)+''' mm
d:Ge/Hole'''+str(h)+'''/HLY2                 = '''+str(HL_big)+''' mm
d:Ge/Hole'''+str(h)+'''/HLX1                 = '''+str(HL_small)+''' mm
d:Ge/Hole'''+str(h)+'''/HLX2                 = '''+str(HL_small)+''' mm
d:Ge/Hole'''+str(h)+'''/HLX3                 = '''+str(HL_big)+''' mm
d:Ge/Hole'''+str(h)+'''/HLX4                 = '''+str(HL_big)+''' mm
d:Ge/Hole'''+str(h)+'''/HLZ                 = '''+str(col_thick/2)+''' mm
d:Ge/Hole'''+str(h)+'''/Theta                 = '''+str(0)+''' deg
d:Ge/Hole'''+str(h)+'''/Alp1                 = 0 deg
d:Ge/Hole'''+str(h)+'''/Alp2                 = 0 deg
d:Ge/Hole'''+str(h)+'''/Phi                 = '''+str(0)+''' deg
s:Ge/Hole'''+str(h)+'''/Color              = "white"
s:Ge/Hole'''+str(h)+'''/DrawingStyle       = "Solid"
s:Ge/Hole'''+str(h)+'''/ParallelWorldName  = "Hole1"
    ''')
                h=h+1

            if ((j<0) and (h<=280) and (h>245) ):
                g8.write('''

s:Ge/Hole'''+str(h)+'''/Type               = "G4GTrap"
b:Ge/Hole'''+str(h)+'''/IsParallel         = "True"
s:Ge/Hole'''+str(h)+'''/Parent             = "Collimator"
s:Ge/Hole'''+str(h)+'''/Material           = "Air"
d:Ge/Hole'''+str(h)+'''/TransX             = '''+str(np.around(j,3))+''' mm
d:Ge/Hole'''+str(h)+'''/TransY             = '''+str(np.around(k,3))+''' mm
d:Ge/Hole'''+str(h)+'''/TransZ             = 0 cm
d:Ge/Hole'''+str(h)+'''/RotX               = 0 deg
d:Ge/Hole'''+str(h)+'''/RotY               = 0 deg
d:Ge/Hole'''+str(h)+'''/RotZ               = 0 deg
d:Ge/Hole'''+str(h)+'''/HLY1                 = '''+str(HL_small)+''' mm
d:Ge/Hole'''+str(h)+'''/HLY2                 = '''+str(HL_big)+''' mm
d:Ge/Hole'''+str(h)+'''/HLX1                 = '''+str(HL_small)+''' mm
d:Ge/Hole'''+str(h)+'''/HLX2                 = '''+str(HL_small)+''' mm
d:Ge/Hole'''+str(h)+'''/HLX3                 = '''+str(HL_big)+''' mm
d:Ge/Hole'''+str(h)+'''/HLX4                 = '''+str(HL_big)+''' mm
d:Ge/Hole'''+str(h)+'''/HLZ                 = '''+str(col_thick/2)+''' mm
d:Ge/Hole'''+str(h)+'''/Theta                 = '''+str(0)+''' deg
d:Ge/Hole'''+str(h)+'''/Alp1                 = 0 deg
d:Ge/Hole'''+str(h)+'''/Alp2                 = 0 deg
d:Ge/Hole'''+str(h)+'''/Phi                 = '''+str(0)+''' deg
s:Ge/Hole'''+str(h)+'''/Color              = "white"
s:Ge/Hole'''+str(h)+'''/DrawingStyle       = "Solid"
s:Ge/Hole'''+str(h)+'''/ParallelWorldName  = "Hole1"
    ''')
                h=h+1
            if ((j>=0) and (h<=245) and (h>210) ):
                
                g7.write('''

s:Ge/Hole'''+str(h)+'''/Type               = "G4GTrap"
b:Ge/Hole'''+str(h)+'''/IsParallel         = "True"
s:Ge/Hole'''+str(h)+'''/Parent             = "Collimator"
s:Ge/Hole'''+str(h)+'''/Material           = "Air"
d:Ge/Hole'''+str(h)+'''/TransX             = '''+str(np.around(j,3))+''' mm
d:Ge/Hole'''+str(h)+'''/TransY             = '''+str(np.around(k,3))+''' mm
d:Ge/Hole'''+str(h)+'''/TransZ             = 0 cm
d:Ge/Hole'''+str(h)+'''/RotX               = 0 deg
d:Ge/Hole'''+str(h)+'''/RotY               = 0 deg
d:Ge/Hole'''+str(h)+'''/RotZ               = 0 deg
d:Ge/Hole'''+str(h)+'''/HLY1                 = '''+str(HL_small)+''' mm
d:Ge/Hole'''+str(h)+'''/HLY2                 = '''+str(HL_big)+''' mm
d:Ge/Hole'''+str(h)+'''/HLX1                 = '''+str(HL_small)+''' mm
d:Ge/Hole'''+str(h)+'''/HLX2                 = '''+str(HL_small)+''' mm
d:Ge/Hole'''+str(h)+'''/HLX3                 = '''+str(HL_big)+''' mm
d:Ge/Hole'''+str(h)+'''/HLX4                 = '''+str(HL_big)+''' mm
d:Ge/Hole'''+str(h)+'''/HLZ                 = '''+str(col_thick/2)+''' mm
d:Ge/Hole'''+str(h)+'''/Theta                 = '''+str(0)+''' deg
d:Ge/Hole'''+str(h)+'''/Alp1                 = 0 deg
d:Ge/Hole'''+str(h)+'''/Alp2                 = 0 deg
d:Ge/Hole'''+str(h)+'''/Phi                 = '''+str(0)+''' deg
s:Ge/Hole'''+str(h)+'''/Color              = "white"
s:Ge/Hole'''+str(h)+'''/DrawingStyle       = "Solid"
s:Ge/Hole'''+str(h)+'''/ParallelWorldName  = "Hole1"
    ''')
                h=h+1

            if ((j<0) and (h<=245) and (h>210) ):
                g7.write('''

s:Ge/Hole'''+str(h)+'''/Type               = "G4GTrap"
b:Ge/Hole'''+str(h)+'''/IsParallel         = "True"
s:Ge/Hole'''+str(h)+'''/Parent             = "Collimator"
s:Ge/Hole'''+str(h)+'''/Material           = "Air"
d:Ge/Hole'''+str(h)+'''/TransX             = '''+str(np.around(j,3))+''' mm
d:Ge/Hole'''+str(h)+'''/TransY             = '''+str(np.around(k,3))+''' mm
d:Ge/Hole'''+str(h)+'''/TransZ             = 0 cm
d:Ge/Hole'''+str(h)+'''/RotX               = 0 deg
d:Ge/Hole'''+str(h)+'''/RotY               = 0 deg
d:Ge/Hole'''+str(h)+'''/RotZ               = 0 deg
d:Ge/Hole'''+str(h)+'''/HLY1                 = '''+str(HL_small)+''' mm
d:Ge/Hole'''+str(h)+'''/HLY2                 = '''+str(HL_big)+''' mm
d:Ge/Hole'''+str(h)+'''/HLX1                 = '''+str(HL_small)+''' mm
d:Ge/Hole'''+str(h)+'''/HLX2                 = '''+str(HL_small)+''' mm
d:Ge/Hole'''+str(h)+'''/HLX3                 = '''+str(HL_big)+''' mm
d:Ge/Hole'''+str(h)+'''/HLX4                 = '''+str(HL_big)+''' mm
d:Ge/Hole'''+str(h)+'''/HLZ                 = '''+str(col_thick/2)+''' mm
d:Ge/Hole'''+str(h)+'''/Theta                 = '''+str(0)+''' deg
d:Ge/Hole'''+str(h)+'''/Alp1                 = 0 deg
d:Ge/Hole'''+str(h)+'''/Alp2                 = 0 deg
d:Ge/Hole'''+str(h)+'''/Phi                 = '''+str(0)+''' deg
s:Ge/Hole'''+str(h)+'''/Color              = "white"
s:Ge/Hole'''+str(h)+'''/DrawingStyle       = "Solid"
s:Ge/Hole'''+str(h)+'''/ParallelWorldName  = "Hole1"
    ''')
                h=h+1

            if ((j>=0) and (h<=210) and (h>175) ):
                
                g6.write('''

s:Ge/Hole'''+str(h)+'''/Type               = "G4GTrap"
b:Ge/Hole'''+str(h)+'''/IsParallel         = "True"
s:Ge/Hole'''+str(h)+'''/Parent             = "Collimator"
s:Ge/Hole'''+str(h)+'''/Material           = "Air"
d:Ge/Hole'''+str(h)+'''/TransX             = '''+str(np.around(j,3))+''' mm
d:Ge/Hole'''+str(h)+'''/TransY             = '''+str(np.around(k,3))+''' mm
d:Ge/Hole'''+str(h)+'''/TransZ             = 0 cm
d:Ge/Hole'''+str(h)+'''/RotX               = 0 deg
d:Ge/Hole'''+str(h)+'''/RotY               = 0 deg
d:Ge/Hole'''+str(h)+'''/RotZ               = 0 deg
d:Ge/Hole'''+str(h)+'''/HLY1                 = '''+str(HL_small)+''' mm
d:Ge/Hole'''+str(h)+'''/HLY2                 = '''+str(HL_big)+''' mm
d:Ge/Hole'''+str(h)+'''/HLX1                 = '''+str(HL_small)+''' mm
d:Ge/Hole'''+str(h)+'''/HLX2                 = '''+str(HL_small)+''' mm
d:Ge/Hole'''+str(h)+'''/HLX3                 = '''+str(HL_big)+''' mm
d:Ge/Hole'''+str(h)+'''/HLX4                 = '''+str(HL_big)+''' mm
d:Ge/Hole'''+str(h)+'''/HLZ                 = '''+str(col_thick/2)+''' mm
d:Ge/Hole'''+str(h)+'''/Theta                 = '''+str(0)+''' deg
d:Ge/Hole'''+str(h)+'''/Alp1                 = 0 deg
d:Ge/Hole'''+str(h)+'''/Alp2                 = 0 deg
d:Ge/Hole'''+str(h)+'''/Phi                 = '''+str(0)+''' deg
s:Ge/Hole'''+str(h)+'''/Color              = "white"
s:Ge/Hole'''+str(h)+'''/DrawingStyle       = "Solid"
s:Ge/Hole'''+str(h)+'''/ParallelWorldName  = "Hole1"
    ''')
                h=h+1

            if ((j<0) and (h<=210) and (h>175) ):
                g6.write('''

s:Ge/Hole'''+str(h)+'''/Type               = "G4GTrap"
b:Ge/Hole'''+str(h)+'''/IsParallel         = "True"
s:Ge/Hole'''+str(h)+'''/Parent             = "Collimator"
s:Ge/Hole'''+str(h)+'''/Material           = "Air"
d:Ge/Hole'''+str(h)+'''/TransX             = '''+str(np.around(j,3))+''' mm
d:Ge/Hole'''+str(h)+'''/TransY             = '''+str(np.around(k,3))+''' mm
d:Ge/Hole'''+str(h)+'''/TransZ             = 0 cm
d:Ge/Hole'''+str(h)+'''/RotX               = 0 deg
d:Ge/Hole'''+str(h)+'''/RotY               = 0 deg
d:Ge/Hole'''+str(h)+'''/RotZ               = 0 deg
d:Ge/Hole'''+str(h)+'''/HLY1                 = '''+str(HL_small)+''' mm
d:Ge/Hole'''+str(h)+'''/HLY2                 = '''+str(HL_big)+''' mm
d:Ge/Hole'''+str(h)+'''/HLX1                 = '''+str(HL_small)+''' mm
d:Ge/Hole'''+str(h)+'''/HLX2                 = '''+str(HL_small)+''' mm
d:Ge/Hole'''+str(h)+'''/HLX3                 = '''+str(HL_big)+''' mm
d:Ge/Hole'''+str(h)+'''/HLX4                 = '''+str(HL_big)+''' mm
d:Ge/Hole'''+str(h)+'''/HLZ                 = '''+str(col_thick/2)+''' mm
d:Ge/Hole'''+str(h)+'''/Theta                 = '''+str(0)+''' deg
d:Ge/Hole'''+str(h)+'''/Alp1                 = 0 deg
d:Ge/Hole'''+str(h)+'''/Alp2                 = 0 deg
d:Ge/Hole'''+str(h)+'''/Phi                 = '''+str(0)+''' deg
s:Ge/Hole'''+str(h)+'''/Color              = "white"
s:Ge/Hole'''+str(h)+'''/DrawingStyle       = "Solid"
s:Ge/Hole'''+str(h)+'''/ParallelWorldName  = "Hole1"
    ''')
                h=h+1

            if ((j>=0) and (h<=175) and (h>140) ):
                
                g5.write('''

s:Ge/Hole'''+str(h)+'''/Type               = "G4GTrap"
b:Ge/Hole'''+str(h)+'''/IsParallel         = "True"
s:Ge/Hole'''+str(h)+'''/Parent             = "Collimator"
s:Ge/Hole'''+str(h)+'''/Material           = "Air"
d:Ge/Hole'''+str(h)+'''/TransX             = '''+str(np.around(j,3))+''' mm
d:Ge/Hole'''+str(h)+'''/TransY             = '''+str(np.around(k,3))+''' mm
d:Ge/Hole'''+str(h)+'''/TransZ             = 0 cm
d:Ge/Hole'''+str(h)+'''/RotX               = 0 deg
d:Ge/Hole'''+str(h)+'''/RotY               = 0 deg
d:Ge/Hole'''+str(h)+'''/RotZ               = 0 deg
d:Ge/Hole'''+str(h)+'''/HLY1                 = '''+str(HL_small)+''' mm
d:Ge/Hole'''+str(h)+'''/HLY2                 = '''+str(HL_big)+''' mm
d:Ge/Hole'''+str(h)+'''/HLX1                 = '''+str(HL_small)+''' mm
d:Ge/Hole'''+str(h)+'''/HLX2                 = '''+str(HL_small)+''' mm
d:Ge/Hole'''+str(h)+'''/HLX3                 = '''+str(HL_big)+''' mm
d:Ge/Hole'''+str(h)+'''/HLX4                 = '''+str(HL_big)+''' mm
d:Ge/Hole'''+str(h)+'''/HLZ                 = '''+str(col_thick/2)+''' mm
d:Ge/Hole'''+str(h)+'''/Theta                 = '''+str(0)+''' deg
d:Ge/Hole'''+str(h)+'''/Alp1                 = 0 deg
d:Ge/Hole'''+str(h)+'''/Alp2                 = 0 deg
d:Ge/Hole'''+str(h)+'''/Phi                 = '''+str(0)+''' deg
s:Ge/Hole'''+str(h)+'''/Color              = "white"
s:Ge/Hole'''+str(h)+'''/DrawingStyle       = "Solid"
s:Ge/Hole'''+str(h)+'''/ParallelWorldName  = "Hole1"
    ''')
                h=h+1

            if ((j<0) and (h<=175) and (h>140) ):
                g5.write('''

s:Ge/Hole'''+str(h)+'''/Type               = "G4GTrap"
b:Ge/Hole'''+str(h)+'''/IsParallel         = "True"
s:Ge/Hole'''+str(h)+'''/Parent             = "Collimator"
s:Ge/Hole'''+str(h)+'''/Material           = "Air"
d:Ge/Hole'''+str(h)+'''/TransX             = '''+str(np.around(j,3))+''' mm
d:Ge/Hole'''+str(h)+'''/TransY             = '''+str(np.around(k,3))+''' mm
d:Ge/Hole'''+str(h)+'''/TransZ             = 0 cm
d:Ge/Hole'''+str(h)+'''/RotX               = 0 deg
d:Ge/Hole'''+str(h)+'''/RotY               = 0 deg
d:Ge/Hole'''+str(h)+'''/RotZ               = 0 deg
d:Ge/Hole'''+str(h)+'''/HLY1                 = '''+str(HL_small)+''' mm
d:Ge/Hole'''+str(h)+'''/HLY2                 = '''+str(HL_big)+''' mm
d:Ge/Hole'''+str(h)+'''/HLX1                 = '''+str(HL_small)+''' mm
d:Ge/Hole'''+str(h)+'''/HLX2                 = '''+str(HL_small)+''' mm
d:Ge/Hole'''+str(h)+'''/HLX3                 = '''+str(HL_big)+''' mm
d:Ge/Hole'''+str(h)+'''/HLX4                 = '''+str(HL_big)+''' mm
d:Ge/Hole'''+str(h)+'''/HLZ                 = '''+str(col_thick/2)+''' mm
d:Ge/Hole'''+str(h)+'''/Theta                 = '''+str(0)+''' deg
d:Ge/Hole'''+str(h)+'''/Alp1                 = 0 deg
d:Ge/Hole'''+str(h)+'''/Alp2                 = 0 deg
d:Ge/Hole'''+str(h)+'''/Phi                 = '''+str(0)+''' deg
s:Ge/Hole'''+str(h)+'''/Color              = "white"
s:Ge/Hole'''+str(h)+'''/DrawingStyle       = "Solid"
s:Ge/Hole'''+str(h)+'''/ParallelWorldName  = "Hole1"
    ''')
                h=h+1
            if ((j>=0) and (h<=140) and (h>105) ):
                
                g4.write('''

s:Ge/Hole'''+str(h)+'''/Type               = "G4GTrap"
b:Ge/Hole'''+str(h)+'''/IsParallel         = "True"
s:Ge/Hole'''+str(h)+'''/Parent             = "Collimator"
s:Ge/Hole'''+str(h)+'''/Material           = "Air"
d:Ge/Hole'''+str(h)+'''/TransX             = '''+str(np.around(j,3))+''' mm
d:Ge/Hole'''+str(h)+'''/TransY             = '''+str(np.around(k,3))+''' mm
d:Ge/Hole'''+str(h)+'''/TransZ             = 0 cm
d:Ge/Hole'''+str(h)+'''/RotX               = 0 deg
d:Ge/Hole'''+str(h)+'''/RotY               = 0 deg
d:Ge/Hole'''+str(h)+'''/RotZ               = 0 deg
d:Ge/Hole'''+str(h)+'''/HLY1                 = '''+str(HL_small)+''' mm
d:Ge/Hole'''+str(h)+'''/HLY2                 = '''+str(HL_big)+''' mm
d:Ge/Hole'''+str(h)+'''/HLX1                 = '''+str(HL_small)+''' mm
d:Ge/Hole'''+str(h)+'''/HLX2                 = '''+str(HL_small)+''' mm
d:Ge/Hole'''+str(h)+'''/HLX3                 = '''+str(HL_big)+''' mm
d:Ge/Hole'''+str(h)+'''/HLX4                 = '''+str(HL_big)+''' mm
d:Ge/Hole'''+str(h)+'''/HLZ                 = '''+str(col_thick/2)+''' mm
d:Ge/Hole'''+str(h)+'''/Theta                 = '''+str(0)+''' deg
d:Ge/Hole'''+str(h)+'''/Alp1                 = 0 deg
d:Ge/Hole'''+str(h)+'''/Alp2                 = 0 deg
d:Ge/Hole'''+str(h)+'''/Phi                 = '''+str(0)+''' deg
s:Ge/Hole'''+str(h)+'''/Color              = "white"
s:Ge/Hole'''+str(h)+'''/DrawingStyle       = "Solid"
s:Ge/Hole'''+str(h)+'''/ParallelWorldName  = "Hole1"
    ''')
                h=h+1

            if ((j<0) and (h<=140) and (h>105) ):
                g4.write('''

s:Ge/Hole'''+str(h)+'''/Type               = "G4GTrap"
b:Ge/Hole'''+str(h)+'''/IsParallel         = "True"
s:Ge/Hole'''+str(h)+'''/Parent             = "Collimator"
s:Ge/Hole'''+str(h)+'''/Material           = "Air"
d:Ge/Hole'''+str(h)+'''/TransX             = '''+str(np.around(j,3))+''' mm
d:Ge/Hole'''+str(h)+'''/TransY             = '''+str(np.around(k,3))+''' mm
d:Ge/Hole'''+str(h)+'''/TransZ             = 0 cm
d:Ge/Hole'''+str(h)+'''/RotX               = 0 deg
d:Ge/Hole'''+str(h)+'''/RotY               = 0 deg
d:Ge/Hole'''+str(h)+'''/RotZ               = 0 deg
d:Ge/Hole'''+str(h)+'''/HLY1                 = '''+str(HL_small)+''' mm
d:Ge/Hole'''+str(h)+'''/HLY2                 = '''+str(HL_big)+''' mm
d:Ge/Hole'''+str(h)+'''/HLX1                 = '''+str(HL_small)+''' mm
d:Ge/Hole'''+str(h)+'''/HLX2                 = '''+str(HL_small)+''' mm
d:Ge/Hole'''+str(h)+'''/HLX3                 = '''+str(HL_big)+''' mm
d:Ge/Hole'''+str(h)+'''/HLX4                 = '''+str(HL_big)+''' mm
d:Ge/Hole'''+str(h)+'''/HLZ                 = '''+str(col_thick/2)+''' mm
d:Ge/Hole'''+str(h)+'''/Theta                 = '''+str(0)+''' deg
d:Ge/Hole'''+str(h)+'''/Alp1                 = 0 deg
d:Ge/Hole'''+str(h)+'''/Alp2                 = 0 deg
d:Ge/Hole'''+str(h)+'''/Phi                 = '''+str(0)+''' deg
s:Ge/Hole'''+str(h)+'''/Color              = "white"
s:Ge/Hole'''+str(h)+'''/DrawingStyle       = "Solid"
s:Ge/Hole'''+str(h)+'''/ParallelWorldName  = "Hole1"
    ''')
                h=h+1
            if ((j>=0) and (h<=105) and (h>70) ):
                
                g3.write('''

s:Ge/Hole'''+str(h)+'''/Type               = "G4GTrap"
b:Ge/Hole'''+str(h)+'''/IsParallel         = "True"
s:Ge/Hole'''+str(h)+'''/Parent             = "Collimator"
s:Ge/Hole'''+str(h)+'''/Material           = "Air"
d:Ge/Hole'''+str(h)+'''/TransX             = '''+str(np.around(j,3))+''' mm
d:Ge/Hole'''+str(h)+'''/TransY             = '''+str(np.around(k,3))+''' mm
d:Ge/Hole'''+str(h)+'''/TransZ             = 0 cm
d:Ge/Hole'''+str(h)+'''/RotX               = 0 deg
d:Ge/Hole'''+str(h)+'''/RotY               = 0 deg
d:Ge/Hole'''+str(h)+'''/RotZ               = 0 deg
d:Ge/Hole'''+str(h)+'''/HLY1                 = '''+str(HL_small)+''' mm
d:Ge/Hole'''+str(h)+'''/HLY2                 = '''+str(HL_big)+''' mm
d:Ge/Hole'''+str(h)+'''/HLX1                 = '''+str(HL_small)+''' mm
d:Ge/Hole'''+str(h)+'''/HLX2                 = '''+str(HL_small)+''' mm
d:Ge/Hole'''+str(h)+'''/HLX3                 = '''+str(HL_big)+''' mm
d:Ge/Hole'''+str(h)+'''/HLX4                 = '''+str(HL_big)+''' mm
d:Ge/Hole'''+str(h)+'''/HLZ                 = '''+str(col_thick/2)+''' mm
d:Ge/Hole'''+str(h)+'''/Theta                 = '''+str(0)+''' deg
d:Ge/Hole'''+str(h)+'''/Alp1                 = 0 deg
d:Ge/Hole'''+str(h)+'''/Alp2                 = 0 deg
d:Ge/Hole'''+str(h)+'''/Phi                 = '''+str(0)+''' deg
s:Ge/Hole'''+str(h)+'''/Color              = "white"
s:Ge/Hole'''+str(h)+'''/DrawingStyle       = "Solid"
s:Ge/Hole'''+str(h)+'''/ParallelWorldName  = "Hole1"
    ''')
                h=h+1

            if ((j<0) and (h<=105) and (h>70) ):
                g3.write('''

s:Ge/Hole'''+str(h)+'''/Type               = "G4GTrap"
b:Ge/Hole'''+str(h)+'''/IsParallel         = "True"
s:Ge/Hole'''+str(h)+'''/Parent             = "Collimator"
s:Ge/Hole'''+str(h)+'''/Material           = "Air"
d:Ge/Hole'''+str(h)+'''/TransX             = '''+str(np.around(j,3))+''' mm
d:Ge/Hole'''+str(h)+'''/TransY             = '''+str(np.around(k,3))+''' mm
d:Ge/Hole'''+str(h)+'''/TransZ             = 0 cm
d:Ge/Hole'''+str(h)+'''/RotX               = 0 deg
d:Ge/Hole'''+str(h)+'''/RotY               = 0 deg
d:Ge/Hole'''+str(h)+'''/RotZ               = 0 deg
d:Ge/Hole'''+str(h)+'''/HLY1                 = '''+str(HL_small)+''' mm
d:Ge/Hole'''+str(h)+'''/HLY2                 = '''+str(HL_big)+''' mm
d:Ge/Hole'''+str(h)+'''/HLX1                 = '''+str(HL_small)+''' mm
d:Ge/Hole'''+str(h)+'''/HLX2                 = '''+str(HL_small)+''' mm
d:Ge/Hole'''+str(h)+'''/HLX3                 = '''+str(HL_big)+''' mm
d:Ge/Hole'''+str(h)+'''/HLX4                 = '''+str(HL_big)+''' mm
d:Ge/Hole'''+str(h)+'''/HLZ                 = '''+str(col_thick/2)+''' mm
d:Ge/Hole'''+str(h)+'''/Theta                 = '''+str(0)+''' deg
d:Ge/Hole'''+str(h)+'''/Alp1                 = 0 deg
d:Ge/Hole'''+str(h)+'''/Alp2                 = 0 deg
d:Ge/Hole'''+str(h)+'''/Phi                 = '''+str(0)+''' deg
s:Ge/Hole'''+str(h)+'''/Color              = "white"
s:Ge/Hole'''+str(h)+'''/DrawingStyle       = "Solid"
s:Ge/Hole'''+str(h)+'''/ParallelWorldName  = "Hole1"
    ''')
                h=h+1
            if ((j>=0) and (h<=70) and (h>35) ):
                
                g2.write('''

s:Ge/Hole'''+str(h)+'''/Type               = "G4GTrap"
b:Ge/Hole'''+str(h)+'''/IsParallel         = "True"
s:Ge/Hole'''+str(h)+'''/Parent             = "Collimator"
s:Ge/Hole'''+str(h)+'''/Material           = "Air"
d:Ge/Hole'''+str(h)+'''/TransX             = '''+str(np.around(j,3))+''' mm
d:Ge/Hole'''+str(h)+'''/TransY             = '''+str(np.around(k,3))+''' mm
d:Ge/Hole'''+str(h)+'''/TransZ             = 0 cm
d:Ge/Hole'''+str(h)+'''/RotX               = 0 deg
d:Ge/Hole'''+str(h)+'''/RotY               = 0 deg
d:Ge/Hole'''+str(h)+'''/RotZ               = 0 deg
d:Ge/Hole'''+str(h)+'''/HLY1                 = '''+str(HL_small)+''' mm
d:Ge/Hole'''+str(h)+'''/HLY2                 = '''+str(HL_big)+''' mm
d:Ge/Hole'''+str(h)+'''/HLX1                 = '''+str(HL_small)+''' mm
d:Ge/Hole'''+str(h)+'''/HLX2                 = '''+str(HL_small)+''' mm
d:Ge/Hole'''+str(h)+'''/HLX3                 = '''+str(HL_big)+''' mm
d:Ge/Hole'''+str(h)+'''/HLX4                 = '''+str(HL_big)+''' mm
d:Ge/Hole'''+str(h)+'''/HLZ                 = '''+str(col_thick/2)+''' mm
d:Ge/Hole'''+str(h)+'''/Theta                 = '''+str(0)+''' deg
d:Ge/Hole'''+str(h)+'''/Alp1                 = 0 deg
d:Ge/Hole'''+str(h)+'''/Alp2                 = 0 deg
d:Ge/Hole'''+str(h)+'''/Phi                 = '''+str(0)+''' deg
s:Ge/Hole'''+str(h)+'''/Color              = "white"
s:Ge/Hole'''+str(h)+'''/DrawingStyle       = "Solid"
s:Ge/Hole'''+str(h)+'''/ParallelWorldName  = "Hole1"
    ''')
                h=h+1

            if ((j<0) and (h<=70) and (h>35) ):
                g2.write('''

s:Ge/Hole'''+str(h)+'''/Type               = "G4GTrap"
b:Ge/Hole'''+str(h)+'''/IsParallel         = "True"
s:Ge/Hole'''+str(h)+'''/Parent             = "Collimator"
s:Ge/Hole'''+str(h)+'''/Material           = "Air"
d:Ge/Hole'''+str(h)+'''/TransX             = '''+str(np.around(j,3))+''' mm
d:Ge/Hole'''+str(h)+'''/TransY             = '''+str(np.around(k,3))+''' mm
d:Ge/Hole'''+str(h)+'''/TransZ             = 0 cm
d:Ge/Hole'''+str(h)+'''/RotX               = 0 deg
d:Ge/Hole'''+str(h)+'''/RotY               = 0 deg
d:Ge/Hole'''+str(h)+'''/RotZ               = 0 deg
d:Ge/Hole'''+str(h)+'''/HLY1                 = '''+str(HL_small)+''' mm
d:Ge/Hole'''+str(h)+'''/HLY2                 = '''+str(HL_big)+''' mm
d:Ge/Hole'''+str(h)+'''/HLX1                 = '''+str(HL_small)+''' mm
d:Ge/Hole'''+str(h)+'''/HLX2                 = '''+str(HL_small)+''' mm
d:Ge/Hole'''+str(h)+'''/HLX3                 = '''+str(HL_big)+''' mm
d:Ge/Hole'''+str(h)+'''/HLX4                 = '''+str(HL_big)+''' mm
d:Ge/Hole'''+str(h)+'''/HLZ                 = '''+str(col_thick/2)+''' mm
d:Ge/Hole'''+str(h)+'''/Theta                 = '''+str(0)+''' deg
d:Ge/Hole'''+str(h)+'''/Alp1                 = 0 deg
d:Ge/Hole'''+str(h)+'''/Alp2                 = 0 deg
d:Ge/Hole'''+str(h)+'''/Phi                 = '''+str(0)+''' deg
s:Ge/Hole'''+str(h)+'''/Color              = "white"
s:Ge/Hole'''+str(h)+'''/DrawingStyle       = "Solid"
s:Ge/Hole'''+str(h)+'''/ParallelWorldName  = "Hole1"
    ''')
                h=h+1
            if ((j>=0) and (h<=35) ):
                
                g.write('''

s:Ge/Hole'''+str(h)+'''/Type               = "G4GTrap"
b:Ge/Hole'''+str(h)+'''/IsParallel         = "True"
s:Ge/Hole'''+str(h)+'''/Parent             = "Collimator"
s:Ge/Hole'''+str(h)+'''/Material           = "Air"
d:Ge/Hole'''+str(h)+'''/TransX             = '''+str(np.around(j,3))+''' mm
d:Ge/Hole'''+str(h)+'''/TransY             = '''+str(np.around(k,3))+''' mm
d:Ge/Hole'''+str(h)+'''/TransZ             = 0 cm
d:Ge/Hole'''+str(h)+'''/RotX               = 0 deg
d:Ge/Hole'''+str(h)+'''/RotY               = 0 deg
d:Ge/Hole'''+str(h)+'''/RotZ               = 0 deg
d:Ge/Hole'''+str(h)+'''/HLY1                 = '''+str(HL_small)+''' mm
d:Ge/Hole'''+str(h)+'''/HLY2                 = '''+str(HL_big)+''' mm
d:Ge/Hole'''+str(h)+'''/HLX1                 = '''+str(HL_small)+''' mm
d:Ge/Hole'''+str(h)+'''/HLX2                 = '''+str(HL_small)+''' mm
d:Ge/Hole'''+str(h)+'''/HLX3                 = '''+str(HL_big)+''' mm
d:Ge/Hole'''+str(h)+'''/HLX4                 = '''+str(HL_big)+''' mm
d:Ge/Hole'''+str(h)+'''/HLZ                 = '''+str(col_thick/2)+''' mm
d:Ge/Hole'''+str(h)+'''/Theta                 = '''+str(0)+''' deg
d:Ge/Hole'''+str(h)+'''/Alp1                 = 0 deg
d:Ge/Hole'''+str(h)+'''/Alp2                 = 0 deg
d:Ge/Hole'''+str(h)+'''/Phi                 = '''+str(0)+''' deg
s:Ge/Hole'''+str(h)+'''/Color              = "white"
s:Ge/Hole'''+str(h)+'''/DrawingStyle       = "Solid"
s:Ge/Hole'''+str(h)+'''/ParallelWorldName  = "Hole1"
    ''')
                h=h+1

            if ((j<0) and (h<=35) ):
                g.write('''

s:Ge/Hole'''+str(h)+'''/Type               = "G4GTrap"
b:Ge/Hole'''+str(h)+'''/IsParallel         = "True"
s:Ge/Hole'''+str(h)+'''/Parent             = "Collimator"
s:Ge/Hole'''+str(h)+'''/Material           = "Air"
d:Ge/Hole'''+str(h)+'''/TransX             = '''+str(np.around(j,3))+''' mm
d:Ge/Hole'''+str(h)+'''/TransY             = '''+str(np.around(k,3))+''' mm
d:Ge/Hole'''+str(h)+'''/TransZ             = 0 cm
d:Ge/Hole'''+str(h)+'''/RotX               = 0 deg
d:Ge/Hole'''+str(h)+'''/RotY               = 0 deg
d:Ge/Hole'''+str(h)+'''/RotZ               = 0 deg
d:Ge/Hole'''+str(h)+'''/HLY1                 = '''+str(HL_small)+''' mm
d:Ge/Hole'''+str(h)+'''/HLY2                 = '''+str(HL_big)+''' mm
d:Ge/Hole'''+str(h)+'''/HLX1                 = '''+str(HL_small)+''' mm
d:Ge/Hole'''+str(h)+'''/HLX2                 = '''+str(HL_small)+''' mm
d:Ge/Hole'''+str(h)+'''/HLX3                 = '''+str(HL_big)+''' mm
d:Ge/Hole'''+str(h)+'''/HLX4                 = '''+str(HL_big)+''' mm
d:Ge/Hole'''+str(h)+'''/HLZ                 = '''+str(col_thick/2)+''' mm
d:Ge/Hole'''+str(h)+'''/Theta                 = '''+str(0)+''' deg
d:Ge/Hole'''+str(h)+'''/Alp1                 = 0 deg
d:Ge/Hole'''+str(h)+'''/Alp2                 = 0 deg
d:Ge/Hole'''+str(h)+'''/Phi                 = '''+str(0)+''' deg
s:Ge/Hole'''+str(h)+'''/Color              = "white"
s:Ge/Hole'''+str(h)+'''/DrawingStyle       = "Solid"
s:Ge/Hole'''+str(h)+'''/ParallelWorldName  = "Hole1"
    ''')
                h=h+1




                
    #d:Ge/Hole'''+str(h)+'''/HLZ                 = '''+str(np.sqrt(z**2+(z*np.tan(j/x*angle*np.pi/180))**2++(z*np.tan(k/x*angle*np.pi/180))**2))+''' mm
    g.close()
    g2.close()
    g3.close()
    g4.close()
    g5.close()
    g6.close()
    g7.close()
    g8.close()
    g9.close()
