# %%
import numpy as np
import matplotlib.pyplot as plt
import xml.etree.ElementTree
from matplotlib.pyplot import figure
for j in np.arange(1,96,6):
    counts = np.genfromtxt("Desktop/CT imaging/30-6-2021/angle_0_acq_{:02d}.mca".format(j), skip_header=16,max_rows=75)
    figure(j,figsize=(9,9))
    plt.plot(np.arange(0,len(counts)),counts)
