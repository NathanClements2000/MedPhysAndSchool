# %%
import numpy as np
for i in np.arange(0,120,0.2):
    print('../bin/topas monox_cdte3x3_3.txt')
    print('sed -i \'133s/{:.4f}/{:.4f}/\' monox_cdte3x3_3.txt'.format((120-i)/1000,(119.8-i)/1000))
    print('sed -i \'134s/{:.1f}/{:.1f}/\' monox_cdte3x3_3.txt'.format(120-i,119.8-i))
# Out:
# cd /root/topas/CdTe
# ../bin/topas monox_cdte3x3_3.txt
# sed -i '133s/0.1200/0.1198/' monox_cdte3x3_3.txt
# sed -i '134s/120.0/119.8/' monox_cdte3x3_3.txt
# cd /root/topas/CdTe
# ../bin/topas monox_cdte3x3_3.txt
# sed -i '133s/0.1198/0.1196/' monox_cdte3x3_3.txt
# sed -i '134s/119.8/119.6/' monox_cdte3x3_3.txt
# cd /root/topas/CdTe
# ../bin/topas monox_cdte3x3_3.txt
# sed -i '133s/0.1196/0.1194/' monox_cdte3x3_3.txt
# sed -i '134s/119.6/119.4/' monox_cdte3x3_3.txt
# cd /root/topas/CdTe
# ../bin/topas monox_cdte3x3_3.txt
# sed -i '133s/0.1194/0.1192/' monox_cdte3x3_3.txt
# sed -i '134s/119.4/119.2/' monox_cdte3x3_3.txt
# cd /root/topas/CdTe
# ../bin/topas monox_cdte3x3_3.txt
# sed -i '133s/0.1192/0.1190/' monox_cdte3x3_3.txt
# sed -i '134s/119.2/119.0/' monox_cdte3x3_3.txt
# cd /root/topas/CdTe
# ../bin/topas monox_cdte3x3_3.txt
# sed -i '133s/0.1190/0.1188/' monox_cdte3x3_3.txt
# sed -i '134s/119.0/118.8/' monox_cdte3x3_3.txt
# cd /root/topas/CdTe
# ../bin/topas monox_cdte3x3_3.txt
# ...
