# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import matplotlib
from scipy.signal import argrelextrema

h=1
angle=5.42454
slit= 3.84
while h<=5:
        print('''s:Ge/Slit_'''+str(h)+'''/Type = "G4GTrap"
b:Ge/Slit_'''+str(h)+'''/IsParallel = "True"
s:Ge/Slit_'''+str(h)+'''/Parent = "Collimator"
s:Ge/Slit_'''+str(h)+'''/Material = "Air"
d:Ge/Slit_'''+str(h)+'''/TransX = '''+str(-slit+0.5*slit*(h-1))+''' mm
d:Ge/Slit_'''+str(h)+'''/TransY = 0. cm
d:Ge/Slit_'''+str(h)+'''/TransZ = 0. cm
d:Ge/Slit_'''+str(h)+'''/RotX = 0. deg
d:Ge/Slit_'''+str(h)+'''/RotY = 0. deg
d:Ge/Slit_'''+str(h)+'''/RotZ = 0. deg
d:Ge/Slit_'''+str(h)+'''/HLY1 = 10.0 mm
d:Ge/Slit_'''+str(h)+'''/HLY2 = 10.0 mm
d:Ge/Slit_'''+str(h)+'''/HLX1 = 0.216 mm
d:Ge/Slit_'''+str(h)+'''/HLX2 = 0.216 mm
d:Ge/Slit_'''+str(h)+'''/HLX3 = 0.595 mm
d:Ge/Slit_'''+str(h)+'''/HLX4 = 0.595 mm
d:Ge/Slit_'''+str(h)+'''/HLZ = 25 mm
d:Ge/Slit_'''+str(h)+'''/Theta = '''+str(-angle+0.5*angle*(h-1))+''' deg
d:Ge/Slit_'''+str(h)+'''/Alp1 = 0. deg
d:Ge/Slit_'''+str(h)+'''/Alp2 = 0. deg
d:Ge/Slit_'''+str(h)+'''/Phi = 0. deg
s:Ge/Slit_'''+str(h)+'''/ParallelWorldName = "Slit_1"
''')
        h=h+1
# Out:
# s:Ge/Slit_1/Type = "G4GTrap"
# b:Ge/Slit_1/IsParallel = "True"
# s:Ge/Slit_1/Parent = "Collimator"
# s:Ge/Slit_1/Material = "Air"
# d:Ge/Slit_1/TransX = -3.84 mm
# d:Ge/Slit_1/TransY = 0. cm
# d:Ge/Slit_1/TransZ = 0. cm
# d:Ge/Slit_1/RotX = 0. deg
# d:Ge/Slit_1/RotY = 0. deg
# d:Ge/Slit_1/RotZ = 0. deg
# d:Ge/Slit_1/HLY1 = 10.0 mm
# d:Ge/Slit_1/HLY2 = 10.0 mm
# d:Ge/Slit_1/HLX1 = 0.216 mm
# d:Ge/Slit_1/HLX2 = 0.216 mm
# d:Ge/Slit_1/HLX3 = 0.595 mm
# d:Ge/Slit_1/HLX4 = 0.595 mm
# d:Ge/Slit_1/HLZ = 25 mm
# d:Ge/Slit_1/Theta = -5.42454 deg
# d:Ge/Slit_1/Alp1 = 0. deg
# d:Ge/Slit_1/Alp2 = 0. deg
# d:Ge/Slit_1/Phi = 0. deg
# s:Ge/Slit_1/ParallelWorldName = "Slit_1"
#
# s:Ge/Slit_2/Type = "G4GTrap"
# b:Ge/Slit_2/IsParallel = "True"
# s:Ge/Slit_2/Parent = "Collimator"
# s:Ge/Slit_2/Material = "Air"
# d:Ge/Slit_2/TransX = -1.92 mm
# d:Ge/Slit_2/TransY = 0. cm
# d:Ge/Slit_2/TransZ = 0. cm
# d:Ge/Slit_2/RotX = 0. deg
# d:Ge/Slit_2/RotY = 0. deg
# d:Ge/Slit_2/RotZ = 0. deg
# ...
