# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import matplotlib
import scipy
from scipy.signal import find_peaks
import pandas as pd

all_data={}
for j in [20]:
    my_array=np.zeros((300,300,100))
    data03=pd.read_csv("D:Desktop/thesis/results/dosetomedium_linac_SFRT_waterphantom"+str(j)+"MeV__1.csv",delimiter= ',',comment='#',names=['x','y','z','dose'])
    for i in np.arange(2,6):
        data1=pd.read_csv("D:Desktop/thesis/results/dosetomedium_linac_SFRT_waterphantom"+str(j)+"MeV__"+str(i)+".csv",delimiter= ',',comment='#',names=['x','y','z','dose'])
        data03.dose=data03.dose + data1.dose
    data03.dose=data03.dose/5/(1.60218e-19)*0.75e-6
    for i in np.arange(0,len(data03.x)):
        my_array[data03.x[i]][data03.y[i]][data03.z[i]]=data03.dose[i]
    all_data[j]=np.array(my_array)

# %%
y= np.arange(0,200)*0.15
x= np.arange(0,200)*0.15
z= np.arange(0,100)*5

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10,5))
im1=ax1.imshow(all_data[20][:,:,0],extent=(0,200*0.15,0,200*0.15))
ax2.imshow(all_data[20][:,100,:].T,aspect='auto',extent=(0,200*0.15,0,100))
ax1.set_ylabel('y (mm)')
ax1.set_xlabel('x (mm)')
ax2.set_ylabel('z (mm)')
ax2.set_xlabel('x (mm)')
fig.colorbar(im1,ax=ax2,label='Gy/s')
fig.suptitle('20 MeV')
fig.tight_layout()

# %%
font = {'family' : 'Arial',
        'weight' : 'normal',
        'size'   : 16}

matplotlib.rc('font', **font)

# %%
x= np.arange(0,200)*0.15+0.15/2
y= np.arange(0,200)*0.15+0.15/2
z= np.arange(0,20)*5+5/2

energies=[100,150,200,250]
for i in energies:
    fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(15,5))
    im1=ax1.imshow(all_data[i][:,:,0],extent=(0,200*0.15,0,200*0.15),vmax=4e3)
    ax3.imshow(all_data[i][:,100,:],aspect='auto',extent=(0,20*5,0,200*0.15),vmax=4e3)
    ax1.set_ylabel('y (mm)')
    ax1.set_xlabel('x (mm)')
    ax1.set_title('2.5 mm depth')
    ax2.set_title('52.5 mm depth')
    ax2.set_ylabel('y (mm)')
    ax2.set_xlabel('x (mm)')
    ax3.set_ylabel('x (mm)')
    ax3.set_xlabel('z (mm)')
    ax3.set_title('2D depth profile')
    ax2.imshow(all_data[i][:,:,10],extent=(0,200*0.15,0,200*0.15),vmax=4e3)
    fig.colorbar(im1,ax=ax3,label='Gy/s')
    fig.suptitle(str(i)+' MV')
    fig.tight_layout()
    


    figure(19,figsize=(8,8))
    avgpdd=np.array([np.mean(all_data[i][98:102,98:102,j]) for j in np.arange(0,len(z))])/10
    avgpdderr=np.array([np.std(all_data[i][98:102,98:102,j]) for j in np.arange(0,len(z))])/10
    plt.plot(z,avgpdd,label='Open beam '+str(i)+' MeV')
    plt.fill_between(z,avgpdd-avgpdderr,avgpdd+avgpdderr,alpha=0.5)
    plt.xlim(0,100)
    plt.ylim(0,4e3/10)
    plt.xlabel('Depth (mm)')
    plt.ylabel('Dose (Gy)')
    plt.legend()
plt.grid()
plt.title('Central axis dose per pulse')
# Out:
# Text(0.5, 1.0, 'Central axis dose per pulse')

# %%
def align_y_axis(ax1, ax2, minresax1, minresax2,numticks):
    """ Sets tick marks of twinx axes to line up with x total tick marks

    ax1 and ax2 are matplotlib axes
    Spacing between tick marks will be a factor of minresax1 and minresax2"""

    ax1ylims = ax1.get_ybound()
    ax2ylims = ax2.get_ybound()
    ax1factor = minresax1 * (numticks-1)
    ax2factor = minresax2 * (numticks-1)
    ax1.set_yticks(np.linspace(ax1ylims[0],
                               ax1ylims[1]+(ax1factor -
                               (ax1ylims[1]-ax1ylims[0]) % ax1factor) %
                               ax1factor,
                               numticks))
    ax2.set_yticks(np.linspace(ax2ylims[0],
                               ax2ylims[1]+(ax2factor -
                               (ax2ylims[1]-ax2ylims[0]) % ax2factor) %
                               ax2factor,
                               numticks))

energy=np.arange(100,250+1,10)


figure(1,figsize=(8,8))
fig, ax1=plt.subplots(figsize=(8,8))
plt.plot(np.arange(100,250+1,10),DOC_energy,marker='o',label='Depth of convergence',markersize=9,c='tab:orange')
plt.ylabel('Depth of convergence (mm)',c='tab:orange')
plt.xlabel('Energy (MeV)')
plt.grid(c='lightgray',axis='both',ls='--')
plt.ylim(bottom=0)
ax2=ax1.twinx()
#plt.plot(np.arange(100,250,10),pvdr_energy,marker='o',markersize=9,label='PVDR')
#plt.ylabel('PVDR',c='tab:blue')
plt.grid(c='lightgray',axis='both',ls='--')
plt.ylim(bottom=0)
fig.legend(loc="upper center", bbox_to_anchor=(0.5,0.8455))
plt.title('Depth test results (water)')

align_y_axis(ax1,ax2,5,5,6)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17580/3846181883.py in <module>
#      25 figure(1,figsize=(8,8))
#      26 fig, ax1=plt.subplots(figsize=(8,8))
# ---> 27 plt.plot(np.arange(100,250+1,10),DOC_energy,marker='o',label='Depth of convergence',markersize=9,c='tab:orange')
#      28 plt.ylabel('Depth of convergence (mm)',c='tab:orange')
#      29 plt.xlabel('Energy (MeV)')
#
# NameError: name 'DOC_energy' is not defined

# %%
figure(3,figsize=(8,8))
plt.plot(z,mean_peaks_avg,label='SFRT 250 MeV')
plt.plot(z,peakPDD150,label='SFRT 150 MeV')
plt.grid()
plt.xlim(0,100)
plt.ylim()
plt.xlabel('Depth (mm)')
plt.ylabel('Dose rate (Gy/s)')
plt.legend()
