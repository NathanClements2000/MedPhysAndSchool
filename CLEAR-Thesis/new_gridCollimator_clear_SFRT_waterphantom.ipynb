# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import matplotlib
from scipy.signal import argrelextrema
from random import randint

for i in [140,175,200]:
    for a in np.arange(1,20+1):
        f = open("D:Desktop/Thesis/new_gridCollimator_clear_SFRT_waterphantom_"+str(i)+"MeV__"+str(a)+".txt", "w")
        g = open("D:Desktop/Thesis/new_moreholes_clear_SFRT_waterphantom_"+str(i)+"MeV__"+str(a)+".txt", "w")
        f.write('''
includeFile = ./new_moreholes_clear_SFRT_waterphantom_'''+str(i)+'''MeV__'''+str(a)+'''.txt

sv:Ph/Default/LayeredMassGeometryWorlds=2 "gridcol" "Hole1"

# graphics
b:Gr/Enable = "False"
Ts/UseQt = "False"

b:Gr/MyOGL/IncludeAxes = "true"
s:Gr/MyOGL/AxesComponent = "World" #"MSC"
d:Gr/MyOGL/AxesSize = 36.5 cm
s:Gr/MyOGL/Type = "OpenGL"
s:Gr/RefreshEvery = "History" #History or Run

#Physics
sv:Ph/Default/Modules = 8 "g4em-standard_opt4" "g4h-phy_QGSP_BIC_HP" "g4decay" "g4ion-binarycascade" "g4h-elastic_HP" "g4stopping" "g4radioactivedecay" "g4em-extra"
d:Ph/Default/CutforAllParticles= 0.004 cm

# Geometry
Ge/World/HLX=4.0 m
Ge/World/HLY=4.0 m
Ge/World/HLZ=4.0 m
b:Ge/World/Invisible = "true"
s:Ge/World/Material = "Air"
s:Ge/World/Color = "white"


#Source Position
s:Ge/BeamPosition/Parent="World"
s:Ge/BeamPosition/Type="Group"
d:Ge/BeamPosition/TransX=0. m
d:Ge/BeamPosition/TransY=0. m
d:Ge/BeamPosition/TransZ= 0 cm
d:Ge/BeamPosition/RotX=0. deg
d:Ge/BeamPosition/RotY=0. deg
d:Ge/BeamPosition/RotZ=0. deg

#Mark source
# s:Ge/DemoBox/Type                    = "TsBox"
# s:Ge/DemoBox/Parent                  = "BeamPosition"
# s:Ge/DemoBox/Material                = "Air"
# d:Ge/DemoBox/TransX                  = 0 cm
# d:Ge/DemoBox/TransY                  = 0 cm
# d:Ge/DemoBox/TransZ                  = 0 cm
# d:Ge/DemoBox/RotX                    = 0 deg
# d:Ge/DemoBox/RotY                    = 0 deg
# d:Ge/DemoBox/RotZ                    = 0 deg
# d:Ge/DemoBox/HLX                     = 0.1 mm
# d:Ge/DemoBox/HLY                     = 0.1 mm
# d:Ge/DemoBox/HLZ                     = 0.1 mm
# s:Ge/DemoBox/Color                   = "white"


#Source
s:So/Source1/Type = "Beam" # Beam, Isotropic, Emittance or PhaseSpace
s:So/Source1/Component = "BeamPosition"
s:So/Source1/BeamParticle = "e-"
d:So/Source1/BeamEnergy = 199.4 MeV
u:So/Source1/BeamEnergySpread = 1.0
s:So/Source1/BeamPositionDistribution = "Gaussian" # None, Flat or Gaussian
s:So/Source1/BeamPositionCutoffShape = "Ellipse" # Rectangle or Ellipse (if Flat or Gaussian)
d:So/Source1/BeamPositionCutoffX = 10. cm # X extent of position (if Flat or Gaussian)
d:So/Source1/BeamPositionCutoffY = 10. cm # Y extent of position (if Flat or Gaussian)
d:So/Source1/BeamPositionSpreadX = 1.3099 mm #  distribution (if Gaussian)
d:So/Source1/BeamPositionSpreadY = 1.9077 mm #  1.5479 1.89 distribution (if Gaussian)
s:So/Source1/BeamAngularDistribution = "Gaussian" # None, Flat or Gaussian
d:So/Source1/BeamAngularCutoffX = 90. deg # X cutoff of angular distrib (if Flat or Gaussian)
d:So/Source1/BeamAngularCutoffY = 90. deg # Y cutoff of angular distrib (if Flat or Gaussian)
d:So/Source1/BeamAngularSpreadX = 0.5168 deg # 0.45 X angular distribution (if Gaussian)
d:So/Source1/BeamAngularSpreadY = 0.5070 deg # 0.4409 0.39 Y angular distribution (if Gaussian)
i:So/Source1/NumberOfHistoriesInRun = 500000

 

# Overall program control
i:Ts/ShowHistoryCountAtInterval = 100 # How often to print history count to the console
b:Ts/ShowCPUTime = "True"
#Ts/ShowHistoryCountOnSingleLine = "True"
s:Ts/PauseForGeant4Commands = "Never"  #"Never" #"BeforeQuit" # Never or one or more of BeforeInit, BeforeSequence, BeforeQuit

#Tungsten
sv:Ma/W_EGS/Components = 1 "Tungsten"
uv:Ma/W_EGS/Fractions = 1 1.0
d:Ma/W_EGS/Density = 19.25 g/cm3
s:Ma/W_EGS/DefaultColor="Gray"
i:Ma/W_EGS/AtomicNumber = 74
d:Ma/W_EGS/AtomicMass = 183.84 g/mole

#Grid collimator
s:Ge/gridcol/Type                    = "TsBox"
s:Ge/gridcol/Parent                  = "World"
s:Ge/gridcol/Material                = "W_EGS"
d:Ge/gridcol/TransX                  = 0 cm
d:Ge/gridcol/TransY                  = 0 cm
d:Ge/gridcol/TransZ                  = '''+str(37.5-2)+''' cm
d:Ge/gridcol/RotX                    = 0 deg
d:Ge/gridcol/RotY                    = 0 deg
d:Ge/gridcol/RotZ                    = 0 deg
d:Ge/gridcol/HLX                     = 7.5 mm
d:Ge/gridcol/HLY                     = 7.5 mm
d:Ge/gridcol/HLZ                     = 10 mm
s:Ge/gridcol/Color                   = "Gray"
b:Ge/gridcol/IsParallel              = "True"
s:Ge/gridcol/ParallelWorldName  = "gridcol"

#Steel collimator holder
s:Ge/holder/Type                    = "TsBox"
s:Ge/holder/Parent                  = "World"
s:Ge/holder/Material                = "Steel"
d:Ge/holder/TransX                  = 0 cm
d:Ge/holder/TransY                  = 0 cm
d:Ge/holder/TransZ                  = '''+str(37.5-2)+''' cm
d:Ge/holder/RotX                    = 0 deg
d:Ge/holder/RotY                    = 0 deg
d:Ge/holder/RotZ                    = 0 deg
d:Ge/holder/HLX                     = 1.75 cm
d:Ge/holder/HLY                     = 2.75 cm
d:Ge/holder/HLZ                     = 1.0 cm
s:Ge/holder/Color                   = "Gray"
s:Ge/holder/DrawingStyle       = "FullWireFrame"



# The phantom
s:Ge/WaterPhantom/Parent = "World"
s:Ge/WaterPhantom/Type   = "TsBox"
s:Ge/WaterPhantom/Material = "G4_WATER"
d:Ge/WaterPhantom/HLX = 7 cm
d:Ge/WaterPhantom/HLY = 5.5 cm
d:Ge/WaterPhantom/HLZ = 21 cm
d:Ge/WaterPhantom/TransX =  0.0 cm
d:Ge/WaterPhantom/TransY =  0.0 cm
d:Ge/WaterPhantom/TransZ =  '''+str(37.5+21)+''' cm
d:Ge/WaterPhantom/RotX= 0. deg
d:Ge/WaterPhantom/RotY= 0. deg
d:Ge/WaterPhantom/RotZ= 0. deg
s:Ge/WaterPhantom/Color = "Blue"
s:Ge/WaterPhantom/DrawingStyle = "FullWireFrame"


# Scoring geometry
s:Ge/Scorebox/Parent = "WaterPhantom"
s:Ge/Scorebox/Type   = "TsBox"
#s:Ge/Scorebox/Material = "G4_WATER"
d:Ge/Scorebox/HLX = 1.25 cm
d:Ge/Scorebox/HLY = 1.25 cm
d:Ge/Scorebox/HLZ = 5 cm
d:Ge/Scorebox/TransX =  0.0 cm
d:Ge/Scorebox/TransY =  0.0 cm
d:Ge/Scorebox/TransZ =  '''+str(-16)+''' cm
d:Ge/Scorebox/RotX= 0. deg
d:Ge/Scorebox/RotY= 0. deg
d:Ge/Scorebox/RotZ= 0. deg
s:Ge/Scorebox/Color = "Red"
s:Ge/Scorebox/DrawingStyle = "Solid"
b:Ge/Scorebox/IsParallel = "True"

s:Sc/WaterPhantomDoseToMedium/OutputFile = "./results/new_dosetomedium__clear_SFRT_waterphantom'''+str(i)+'''MeV__'''+str(a)+'''"
i:Ts/Seed ='''+str(randint(2,800000))+'''

i:Sc/WaterPhantomDoseToMedium/XBins = 250
i:Sc/WaterPhantomDoseToMedium/YBins = 250
i:Sc/WaterPhantomDoseToMedium/ZBins = 400

sv:Sc/WaterPhantomDoseToMedium/Report = 1 "Mean" # One or more of Sum, Mean, Histories, Count_In_Bin, Second_Moment, Variance, Standard_Deviation, Min, Max
s:Sc/WaterPhantomDoseToMedium/Quantity                         = "DoseToMedium"
s:Sc/WaterPhantomDoseToMedium/Component                        = "Scorebox"
b:Sc/WaterPhantomDoseToMedium/OutputToConsole                  = "FALSE"
s:Sc/WaterPhantomDoseToMedium/IfOutputFileAlreadyExists        = "Overwrite"

s:Sc/GammaprimaryDoseToMedium/OutputFile = "./results/new_gammaprimary_clear_SFRT_waterphantom'''+str(i)+'''MeV__'''+str(a)+'''"
i:Sc/GammaprimaryDoseToMedium/XBins = 250
i:Sc/GammaprimaryDoseToMedium/YBins = 250
i:Sc/GammaprimaryDoseToMedium/ZBins = 400

sv:Sc/GammaprimaryDoseToMedium/Report = 1 "Mean" # One or more of Sum, Mean, Histories, Count_In_Bin, Second_Moment, Variance, Standard_Deviation, Min, Max
s:Sc/GammaprimaryDoseToMedium/Quantity                         = "DoseToMedium"
s:Sc/GammaprimaryDoseToMedium/Component                        = "Scorebox"
b:Sc/GammaprimaryDoseToMedium/OutputToConsole                  = "FALSE"
s:Sc/GammaprimaryDoseToMedium/IfOutputFileAlreadyExists        = "Overwrite"
sv:Sc/Gammaprimary/OnlyIncludeIfParticleOrAncestorNamed = 1 "gamma"



''')

                #Everything in mm
        #SCD=22
        col_thick= 20
        small_slit=0.5
        big_slit=0.5
        small_sep=1.1
        big_sep= 1.1
        HL_small=small_slit/2
        HL_big=big_slit/2
        x=big_sep+big_slit
        #z=col_thick/2+SCD
        holes=7
        #angle=np.arctan(x/z)*180/np.pi
        h=1
        for j in np.arange(-(holes-1)/2*x,(holes-1)/2*x+x-0.001,x):
            for k in np.arange(-(holes-1)/2*x,(holes-1)/2*x+x-0.001,x):
                if ((j>=0) and (h>30)):
                    g.write('''

s:Ge/Hole'''+str(h)+'''/Type               = "G4GTrap"
b:Ge/Hole'''+str(h)+'''/IsParallel         = "True"
s:Ge/Hole'''+str(h)+'''/Parent             = "World"
s:Ge/Hole'''+str(h)+'''/Material           = "Air"
d:Ge/Hole'''+str(h)+'''/TransX             = '''+str(np.around(j,3))+''' mm
d:Ge/Hole'''+str(h)+'''/TransY             = '''+str(np.around(k,3))+''' mm
d:Ge/Hole'''+str(h)+'''/TransZ             = '''+str(37.5-2)+''' cm
d:Ge/Hole'''+str(h)+'''/RotX               = 0 deg
d:Ge/Hole'''+str(h)+'''/RotY               = 0 deg
d:Ge/Hole'''+str(h)+'''/RotZ               = 0 deg
d:Ge/Hole'''+str(h)+'''/HLY1                 = '''+str(HL_small)+''' mm
d:Ge/Hole'''+str(h)+'''/HLY2                 = '''+str(HL_big)+''' mm
d:Ge/Hole'''+str(h)+'''/HLX1                 = '''+str(HL_small)+''' mm
d:Ge/Hole'''+str(h)+'''/HLX2                 = '''+str(HL_small)+''' mm
d:Ge/Hole'''+str(h)+'''/HLX3                 = '''+str(HL_big)+''' mm
d:Ge/Hole'''+str(h)+'''/HLX4                 = '''+str(HL_big)+''' mm
d:Ge/Hole'''+str(h)+'''/HLZ                 = '''+str(col_thick/2)+''' mm
d:Ge/Hole'''+str(h)+'''/Theta                 = '''+str(0)+''' deg
d:Ge/Hole'''+str(h)+'''/Alp1                 = 0 deg
d:Ge/Hole'''+str(h)+'''/Alp2                 = 0 deg
d:Ge/Hole'''+str(h)+'''/Phi                 = '''+str(0)+''' deg
s:Ge/Hole'''+str(h)+'''/Color              = "white"
s:Ge/Hole'''+str(h)+'''/DrawingStyle       = "Solid"
s:Ge/Hole'''+str(h)+'''/ParallelWorldName  = "Hole1"
    ''')
                    h=h+1
                if ((j<0) and (h>30)):
                    g.write('''

s:Ge/Hole'''+str(h)+'''/Type               = "G4GTrap"
b:Ge/Hole'''+str(h)+'''/IsParallel         = "True"
s:Ge/Hole'''+str(h)+'''/Parent             = "World"
s:Ge/Hole'''+str(h)+'''/Material           = "Air"
d:Ge/Hole'''+str(h)+'''/TransX             = '''+str(np.around(j,3))+''' mm
d:Ge/Hole'''+str(h)+'''/TransY             = '''+str(np.around(k,3))+''' mm
d:Ge/Hole'''+str(h)+'''/TransZ             = '''+str(37.5-2)+''' cm
d:Ge/Hole'''+str(h)+'''/RotX               = 0 deg
d:Ge/Hole'''+str(h)+'''/RotY               = 0 deg
d:Ge/Hole'''+str(h)+'''/RotZ               = 0 deg
d:Ge/Hole'''+str(h)+'''/HLY1                 = '''+str(HL_small)+''' mm
d:Ge/Hole'''+str(h)+'''/HLY2                 = '''+str(HL_big)+''' mm
d:Ge/Hole'''+str(h)+'''/HLX1                 = '''+str(HL_small)+''' mm
d:Ge/Hole'''+str(h)+'''/HLX2                 = '''+str(HL_small)+''' mm
d:Ge/Hole'''+str(h)+'''/HLX3                 = '''+str(HL_big)+''' mm
d:Ge/Hole'''+str(h)+'''/HLX4                 = '''+str(HL_big)+''' mm
d:Ge/Hole'''+str(h)+'''/HLZ                 = '''+str(col_thick/2)+''' mm
d:Ge/Hole'''+str(h)+'''/Theta                 = '''+str(0)+''' deg
d:Ge/Hole'''+str(h)+'''/Alp1                 = 0 deg
d:Ge/Hole'''+str(h)+'''/Alp2                 = 0 deg
d:Ge/Hole'''+str(h)+'''/Phi                 = '''+str(0)+''' deg
s:Ge/Hole'''+str(h)+'''/Color              = "white"
s:Ge/Hole'''+str(h)+'''/DrawingStyle       = "Solid"
s:Ge/Hole'''+str(h)+'''/ParallelWorldName  = "Hole1"
    ''')

                    h=h+1
                if ((j>=0) and (h<=30)):
                
                    f.write('''

s:Ge/Hole'''+str(h)+'''/Type               = "G4GTrap"
b:Ge/Hole'''+str(h)+'''/IsParallel         = "True"
s:Ge/Hole'''+str(h)+'''/Parent             = "World"
s:Ge/Hole'''+str(h)+'''/Material           = "Air"
d:Ge/Hole'''+str(h)+'''/TransX             = '''+str(np.around(j,3))+''' mm
d:Ge/Hole'''+str(h)+'''/TransY             = '''+str(np.around(k,3))+''' mm
d:Ge/Hole'''+str(h)+'''/TransZ             = '''+str(37.5-2)+''' cm
d:Ge/Hole'''+str(h)+'''/RotX               = 0 deg
d:Ge/Hole'''+str(h)+'''/RotY               = 0 deg
d:Ge/Hole'''+str(h)+'''/RotZ               = 0 deg
d:Ge/Hole'''+str(h)+'''/HLY1                 = '''+str(HL_small)+''' mm
d:Ge/Hole'''+str(h)+'''/HLY2                 = '''+str(HL_big)+''' mm
d:Ge/Hole'''+str(h)+'''/HLX1                 = '''+str(HL_small)+''' mm
d:Ge/Hole'''+str(h)+'''/HLX2                 = '''+str(HL_small)+''' mm
d:Ge/Hole'''+str(h)+'''/HLX3                 = '''+str(HL_big)+''' mm
d:Ge/Hole'''+str(h)+'''/HLX4                 = '''+str(HL_big)+''' mm
d:Ge/Hole'''+str(h)+'''/HLZ                 = '''+str(col_thick/2)+''' mm
d:Ge/Hole'''+str(h)+'''/Theta                 = '''+str(0)+''' deg
d:Ge/Hole'''+str(h)+'''/Alp1                 = 0 deg
d:Ge/Hole'''+str(h)+'''/Alp2                 = 0 deg
d:Ge/Hole'''+str(h)+'''/Phi                 = '''+str(0)+''' deg
s:Ge/Hole'''+str(h)+'''/Color              = "white"
s:Ge/Hole'''+str(h)+'''/DrawingStyle       = "Solid"
s:Ge/Hole'''+str(h)+'''/ParallelWorldName  = "Hole1"
    ''')
                    h=h+1

                if ((j<0) and (h<=30)):
                    f.write('''

s:Ge/Hole'''+str(h)+'''/Type               = "G4GTrap"
b:Ge/Hole'''+str(h)+'''/IsParallel         = "True"
s:Ge/Hole'''+str(h)+'''/Parent             = "World"
s:Ge/Hole'''+str(h)+'''/Material           = "Air"
d:Ge/Hole'''+str(h)+'''/TransX             = '''+str(np.around(j,3))+''' mm
d:Ge/Hole'''+str(h)+'''/TransY             = '''+str(np.around(k,3))+''' mm
d:Ge/Hole'''+str(h)+'''/TransZ             = '''+str(37.5-2)+''' cm
d:Ge/Hole'''+str(h)+'''/RotX               = 0 deg
d:Ge/Hole'''+str(h)+'''/RotY               = 0 deg
d:Ge/Hole'''+str(h)+'''/RotZ               = 0 deg
d:Ge/Hole'''+str(h)+'''/HLY1                 = '''+str(HL_small)+''' mm
d:Ge/Hole'''+str(h)+'''/HLY2                 = '''+str(HL_big)+''' mm
d:Ge/Hole'''+str(h)+'''/HLX1                 = '''+str(HL_small)+''' mm
d:Ge/Hole'''+str(h)+'''/HLX2                 = '''+str(HL_small)+''' mm
d:Ge/Hole'''+str(h)+'''/HLX3                 = '''+str(HL_big)+''' mm
d:Ge/Hole'''+str(h)+'''/HLX4                 = '''+str(HL_big)+''' mm
d:Ge/Hole'''+str(h)+'''/HLZ                 = '''+str(col_thick/2)+''' mm
d:Ge/Hole'''+str(h)+'''/Theta                 = '''+str(0)+''' deg
d:Ge/Hole'''+str(h)+'''/Alp1                 = 0 deg
d:Ge/Hole'''+str(h)+'''/Alp2                 = 0 deg
d:Ge/Hole'''+str(h)+'''/Phi                 = '''+str(0)+''' deg
s:Ge/Hole'''+str(h)+'''/Color              = "white"
s:Ge/Hole'''+str(h)+'''/DrawingStyle       = "Solid"
s:Ge/Hole'''+str(h)+'''/ParallelWorldName  = "Hole1"
    ''')
                    h=h+1


        g.close()
