# %%
import numpy as np
for i in np.arange(700,1001):
    print('"PatientTissueFromHUNegative'+str(i)+'"')
# Out:
# "PatientTissueFromHUNegative700"
# "PatientTissueFromHUNegative701"
# "PatientTissueFromHUNegative702"
# "PatientTissueFromHUNegative703"
# "PatientTissueFromHUNegative704"
# "PatientTissueFromHUNegative705"
# "PatientTissueFromHUNegative706"
# "PatientTissueFromHUNegative707"
# "PatientTissueFromHUNegative708"
# "PatientTissueFromHUNegative709"
# "PatientTissueFromHUNegative710"
# "PatientTissueFromHUNegative711"
# "PatientTissueFromHUNegative712"
# "PatientTissueFromHUNegative713"
# "PatientTissueFromHUNegative714"
# "PatientTissueFromHUNegative715"
# "PatientTissueFromHUNegative716"
# "PatientTissueFromHUNegative717"
# "PatientTissueFromHUNegative718"
# "PatientTissueFromHUNegative719"
# "PatientTissueFromHUNegative720"
# "PatientTissueFromHUNegative721"
# "PatientTissueFromHUNegative722"
# "PatientTissueFromHUNegative723"
# "PatientTissueFromHUNegative724"
# "PatientTissueFromHUNegative725"
# "PatientTissueFromHUNegative726"
# "PatientTissueFromHUNegative727"
# ...
