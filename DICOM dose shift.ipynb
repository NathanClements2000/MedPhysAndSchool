# %%
import pydicom
from pydicom.data import get_testdata_file
import numpy as np
# get some test data
ds = pydicom.dcmread("d:/Desktop/SFRT-Topas/vhee/vhee_patient/results/dosetomedium_vhee_sfrt_patient_test_100MV_tumor.dcm")
print(ds)
print(ds[0x0020, 0x0032].value)
ds[0x0020, 0x0032].value= [163.5935,155.156,-811.09]
ds.PatientName = '100 MV 10k no air'
print(ds)
ds.save_as("d:/Desktop/SFRT-Topas/vhee/vhee_patient/results/dosetomedium_vhee_sfrt_patient_test_100MV_tumor.dcm")
# Out:
# Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 236
# (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: RT Dose Storage
# (0002, 0003) Media Storage SOP Instance UID      UI: 1.2.826.0.1.3680043.9.5871.7489252351152172943577847226023364386
# (0002, 0010) Transfer Syntax UID                 UI: Implicit VR Little Endian
# (0002, 0012) Implementation Class UID            UI: 1.2.826.0.1.3680043.2.1143.107.104.103.115.2.6.8
# (0002, 0013) Implementation Version Name         SH: 'GDCM 2.6.8'
# (0002, 0016) Source Application Entity Title     AE: 'GDCM'
# -------------------------------------------------
# (0008, 0008) Image Type                          CS: ''
# (0008, 0012) Instance Creation Date              DA: '20220615'
# (0008, 0013) Instance Creation Time              TM: '155858'
# (0008, 0016) SOP Class UID                       UI: RT Dose Storage
# ...
